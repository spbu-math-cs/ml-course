# %% [markdown]
# <center><img src="./images/logo_fmkn.png" width=300 style="display: inline-block;"></center>
#
# ## Машинное обучение 2
# ### Семинар 1. Полносвязная нейронная сеть
#
# <br />
# <br />
# 17 февраля 2022

# %% [markdown]
# В этом задании мы реализуем и потренируем настоящую нейроную сеть своими руками, «from scratch»!
#
# Нам нужно будет просто составить несколько линейных классификаторов вместе :)
#
# <center><img src="./images/more_layers.png" width=400></center>

# %%
import io
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import scipy.io as scipyio
import urllib.request

from copy import deepcopy

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Загружаем и «готовим» данные

# %%
def load_data_mat(path_to_file, max_samples, seed=7):
#     with urllib.request.urlopen(url) as url, io.open('tmp.mat', 'wb+') as tmp_file:
#         raw_bytes = url.read()
#         tmp_file.write(raw_bytes)

    # load data to your machine and then
    with io.open(path_to_file, 'rb+') as tmp_file:
        raw_mat = scipyio.loadmat(tmp_file)
    
    X = raw_mat['X']  # Array of [32, 32, 3, n_samples]
    y = raw_mat['y']  # Array of [n_samples, 1]
    X = np.moveaxis(X, [3], [0])
    y = y.flatten()
    # Fix up class 0 to be 0
    y[y == 10] = 0
    
    np.random.seed(seed)
    samples = np.random.choice(np.arange(X.shape[0]),
                               max_samples,
                               replace=False)
    
    return X[samples].astype(np.float32), y[samples]

# %%
# %%time
# from http://ufldl.stanford.edu/housenumbers/train_32x32.mat
train_X, train_y = load_data_mat('train_32x32.mat', max_samples=10000)
# Out:
# CPU times: user 2.17 s, sys: 375 ms, total: 2.55 s
# Wall time: 2.58 s

# %%
# %%time
# from http://ufldl.stanford.edu/housenumbers/test_32x32.mat
test_X, test_y = load_data_mat('test_32x32.mat', max_samples=1000)
# Out:
# CPU times: user 2.12 s, sys: 188 ms, total: 2.31 s
# Wall time: 2.38 s

# %%
train_X.shape
# Out:
# (10000, 32, 32, 3)

# %%
fig, gs = plt.figure(figsize=(18, 8)), matplotlib.gridspec.GridSpec(2, 4)

for i in range(8):
    plot = fig.add_subplot(gs[i])
    plot.imshow(train_X[i].astype(int))

plt.show()

# %%
def prepare_for_neural_network(train_X, test_X):
    train_flat = train_X.reshape(train_X.shape[0], -1).astype(np.float64) / 255.0
    test_flat = test_X.reshape(test_X.shape[0], -1).astype(np.float64) / 255.0
    
    # minus mean for centering
    mean_image = np.mean(train_flat, axis=0)
    train_flat -= mean_image
    test_flat -= mean_image
    
    return train_flat, test_flat

def random_split_train_val(X, y, num_val, seed=42):
    np.random.seed(seed)

    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    train_indices = indices[:-num_val]
    train_X = X[train_indices]
    train_y = y[train_indices]

    val_indices = indices[-num_val:]
    val_X = X[val_indices]
    val_y = y[val_indices]

    return train_X, train_y, val_X, val_y

# %% [markdown]
# И ещё разделяем данные на training и validation

# %%
train_X, test_X = prepare_for_neural_network(train_X, test_X)

# split train into train and val
train_X, train_y, val_X, val_y = random_split_train_val(train_X, train_y, num_val=1000)

# %%
train_X.shape
# Out:
# (9000, 3072)

# %% [markdown]
# ### Обязательно будем себя проверять

# %% [markdown]
# Вообще в этой части курса мы будем писать много функций, которые вычисляют градиенты аналитическим методом.
#
# Все функции, в которых мы будем вычислять градиенты, будут написаны по одной и той же схеме.
# Они будут получать на вход точку, где нужно вычислить значение и градиент функции, а на выходе будут выдавать кортеж (tuple) из двух значений — собственно значения функции в этой точке (всегда одно число) и аналитического значения градиента в той же точке (той же размерности, что и вход).
# ```
# def f(x):
#     r"""
#     Computes function and analytic gradient at `x`
#
#     Parameters
#     ----------
#     x : ndarray of float
#       Input to the function
#
#     Returns
#     -------
#     value : float
#       Value of the function
#     grad : ndarray of float
#       Same shape as `x`
#     """
#     ...
#
#     return value, grad
# ```
#
# Необходимым инструментом во время реализации кода, вычисляющего градиенты, является функция его проверки. Эта функция вычисляет градиент численным методом и сверяет результат с градиентом, вычисленным аналитическим методом.
#
# Для проверки мы будем использовать функции, которые вычисляют градиент с помощью численной производной для каждой координаты. Для вычисления производной используем так называемую two-point formula (https://en.wikipedia.org/wiki/Numerical_differentiation):
#
# $$ \frac{f(x+\delta)-f(x-\delta)}{2\delta}$$

# %%
def check_gradient(f, x, delta=1e-5, tol=1e-4):
    r"""
    Checks the implementation of analytical gradient by comparing
    it to numerical gradient using two-point formula

    Parameters
    ----------
    f 
      Function that receives `x` and computes value and gradient
    x : ndarray
      Initial point where gradient is checked
    delta : float
      Step to compute numerical gradient
    tol: float 
      Tolerance for comparing numerical and analytical gradient

    Returns
    -------
      Bool indicating whether gradients match or not
    """
    assert isinstance(x, np.ndarray)
    assert x.dtype == np.float64

    fx, analytic_grad = f(x)
    analytic_grad = analytic_grad.copy()

    assert analytic_grad.shape == x.shape

    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    while not it.finished:
        ix = it.multi_index
        analytic_grad_at_ix = analytic_grad[ix]
        numeric_grad_at_ix = 0

        delta_array = np.zeros(x.shape)
        delta_array[ix] = delta
        fx_add_delta, _ = f(x + delta_array)
        fx_sub_delta, _ = f(x - delta_array)

        numeric_grad_at_ix = (fx_add_delta - fx_sub_delta) / (2 * delta)

        if not np.isclose(numeric_grad_at_ix, analytic_grad_at_ix, tol):
            print("Gradients are different at %s. Analytic: %2.5f, Numeric: %2.5f" % (
                  ix, analytic_grad_at_ix, numeric_grad_at_ix))
            return False

        it.iternext()

    print("Gradient check passed!")
    return True


def check_layer_gradient(layer, x, delta=1e-5, tol=1e-4):
    r"""
    Checks gradient correctness for the input and output of a layer

    Parameters
    ----------
    layer 
      Neural network layer, with forward and backward functions
    x
      Starting point for layer input
    delta : float
      Step to compute numerical gradient
    tol : float
      Tolerance for comparing numerical and analytical gradient

    Returns
    -------
      Bool indicating whether gradients match or not
    """
    output = layer.forward(x)
    output_weight = np.random.randn(*output.shape)

    def helper_func(x):
        output = layer.forward(x)
        loss = np.sum(output * output_weight)
        d_out = np.ones_like(output) * output_weight
        grad = layer.backward(d_out)
        return loss, grad

    return check_gradient(helper_func, x, delta, tol)


def check_layer_param_gradient(layer, x,
                               param_name,
                               delta=1e-5, tol=1e-4):
    r"""
    Checks gradient correctness for the parameter of the layer

    Parameters
    ----------
    layer
      Neural network layer, with forward and backward functions
    x
      Starting point for layer input
    param_name
      Name of the parameter
    delta : float
      Step to compute numerical gradient
    tol : float
      Tolerance for comparing numerical and analytical gradient

    Returns
    -------
      Bool indicating whether gradients match or not
    """
    param = layer.params()[param_name]
    initial_w = param.value

    output = layer.forward(x)
    output_weight = np.random.randn(*output.shape)

    def helper_func(w):
        param.value = w
        output = layer.forward(x)
        loss = np.sum(output * output_weight)
        d_out = np.ones_like(output) * output_weight
        layer.backward(d_out)
        grad = param.grad
        return loss, grad

    return check_gradient(helper_func, initial_w, delta, tol)


def check_model_gradient(model, X, y,
                         delta=1e-5, tol=1e-4):
    """
    Checks gradient correctness for all model parameters

    Parameters
    ----------
    model
      Neural network model with compute_loss_and_gradients
    X : ndarray
      Batch of input data
    y : ndarray
      Batch of labels
    delta : float 
      Step to compute numerical gradient
    tol : float
      Tolerance for comparing numerical and analytical gradient

    Returns
    -------
      Bool indicating whether gradients match or not
    """
    params = model.params()

    for param_key in params:
        print("Checking gradient for %s" % param_key)
        param = params[param_key]
        initial_w = param.value

        def helper_func(w):
            param.value = w
            loss = model.compute_loss_and_gradients(X, y)
            grad = param.grad
            return loss, grad

        if not check_gradient(helper_func, initial_w, delta, tol):
            return False

    return True

# %% [markdown]
# ### Как всегда, начинаем с кирпичиков
#
# Мы будем реализовывать необходимые нам слои по очереди. Каждый слой должен реализовать:
# - прямой проход (forward pass), который генерирует выход слоя по входу и запоминает необходимые данные
# - обратный проход (backward pass), который получает градиент по выходу слоя и вычисляет градиент по входу и по параметрам
#
# Начнем с `ReLU`, у которого параметров нет.

# %%
class ReLULayer:
    def __init__(self):
        self.X = None

    def forward(self, X):
        # TODO: Implement forward pass
        # Hint: you'll need to save some information about X
        # to use it later in the backward pass
        self.X = X
        return np.maximum(X, 0)

    def backward(self, d_out):
        r"""
        Backward pass

        Parameters
        ----------
        d_out : ndarray, shape(batch_size, num_features)
            Gradient of loss function with respect to output

        Returns
        -------
        d_result : ndarray, shape(batch_size, num_features)
            Gradient with respect to input
        """
        # TODO: Implement backward pass
        # Your final implementation shouldn't have any loops
        d_result = d_out * (self.X > 0)
        return d_result

    def params(self):
        # ReLU Doesn't have any parameters
        return {}

# %%
# DONE: Implement ReLULayer layer in layers.py
# Note: you'll need to copy implementation of the gradient_check function from the previous assignment

X = np.array([[1,-2,3],
              [-1, 2, 0.1]
              ])

assert check_layer_gradient(ReLULayer(), X)
# Out:
# Gradient check passed!

# %% [markdown]
# А теперь реализуем полносвязный слой (fully connected layer), у которого будет два массива параметров: W (weights) и B (bias).
#
# Все параметры наши слои будут использовать для параметров специальный класс `Param`, в котором будут храниться значения параметров и градиенты этих параметров, вычисляемые во время обратного прохода.
#
# Это даст возможность аккумулировать (суммировать) градиенты из разных частей функции потерь, например, из `cross-entropy loss` и `regularization loss`.

# %%
class Param:
    r"""
    Trainable parameter of the model
    Captures both parameter value and the gradient
    """

    def __init__(self, value):
        self.value = value
        self.grad = np.zeros_like(self.value)

# %%
class FullyConnectedLayer:
    def __init__(self, n_input, n_output):
        self.W = Param(0.001 * np.random.randn(n_input, n_output))
        self.B = Param(0.001 * np.random.randn(1, n_output))
#         self.W = Param(np.random.normal(0, sqrt(2 / n_input), (n_input, n_output)))
#         self.B = Param(np.random.normal(0, sqrt(2 / n_input), n_output))
        self.X = None

    def forward(self, X):
        # TODO: Implement forward pass
        # Your final implementation shouldn't have any loops
        self.X = deepcopy(X)

        return (X @ self.W.value) + self.B.value

    def backward(self, d_out):
        r"""
        Backward pass
        Computes gradient with respect to input and
        accumulates gradients within self.W and self.B

        Parameters
        ----------
        d_out, ndarray of shape(batch_size, n_output)
          Gradient of loss function with respect to output

        Returns
        -------
        d_result : ndarray of shape(batch_size, n_input) 
          Gradient with respect to input
        """
        # TODO: Implement backward pass
        # Compute both gradient with respect to input
        # and gradients with respect to W and B
        # Add gradients of W and B to their `grad` attribute
        d_input = d_out @ self.W.value.T
        self.W.grad += self.X.T @ d_out
        self.B.grad += np.sum(d_out, axis=0)

        return d_input

    def params(self):
        return {'W': self.W, 'B': self.B}

# %%
assert check_layer_gradient(FullyConnectedLayer(3, 4), X)

assert check_layer_param_gradient(FullyConnectedLayer(3, 4), X, 'W')
assert check_layer_param_gradient(FullyConnectedLayer(3, 4), X, 'B')
# Out:
# Gradient check passed!
# Gradient check passed!
# Gradient check passed!

# %% [markdown]
# ### Вспомогательные функции для реализации нейросети

# %%
def convert_1d_to_2d_array(array):
    r"""Util function to convert array"""
    if(array.ndim == 1):
        return array[np.newaxis, :].copy()
    else:
        return array.copy()

def softmax_with_cross_entropy(predictions, target_index):
    r"""Computes softmax and cross-entropy loss for model predictions,
    including the gradient.

    Parameters
    ----------
    predictions : ndarray, shape(num_classes) or shape(batch_size, num_classes)
        Classifier output.
    target_index : ndarray, shape(1) or shape(batch_size)
        Index(indices) of the true class(es) for given sample(s).

    Returns
    -------
    loss : float
        Computed cross-entropy loss value.
    dpredictions : ndarray
        Array, with the same shape as `predictions`. Gradient of loss value
        with respect to predictions.
    """
    # TODO: implement softmax_with_cross_entropy
    # Your final implementation shouldn't have any loops
    assert isinstance(predictions, np.ndarray)

    is_1D = (predictions.ndim == 1)
    predictions = convert_1d_to_2d_array(predictions)
    batch_size = predictions.shape[0]

    predictions -= np.max(predictions, axis=1)[:, np.newaxis]
    predictions = np.exp(predictions)

    probs = predictions / np.sum(predictions, axis=1)[:, np.newaxis]

    dprediction = probs.copy()
    dprediction[(np.arange(batch_size), target_index)] -= 1
    dprediction /= batch_size
    if (is_1D):
        dprediction = np.squeeze(dprediction, axis=0)

    loss_arr = -np.log(probs)
    loss = np.sum(loss_arr[(np.arange(batch_size), target_index)]) / batch_size
    return loss, dprediction
    

def l2_regularization(W, reg_strength):
    r"""Computes L2 regularization loss on weights and its gradient.

    Parameters
    ----------
    W : ndarray, shape(num_features, num_classes)
        Weights.
    reg_strength : float
        Strength of regularization.

    Returns
    -------
    loss : float
        L2 regularization loss.
    gradient : ndarray, shape(num_features, num_classes)
        Gradient of L2 loss value with respect to weights.
    """
    # TODO: implement l2_regularization
    # Your final implementation shouldn't have any loops
    loss = reg_strength * np.sum(np.square(W))
    grad = 2 * reg_strength * W

    return loss, grad

# %% [markdown]
# ### Создаем нейронную сеть
#
# Теперь мы реализуем простейшую нейронную сеть с двумя полносвязным слоями и нелинейностью ReLU. Реализуйте функцию `compute_loss_and_gradients`, она должна запустить прямой и обратный проход через оба слоя для вычисления градиентов.
#
# Не забудьте реализовать очистку градиентов в начале функции.

# %%
class TwoLayerNet:
    r""" Neural network with two fully connected layers """

    def __init__(self, n_input, n_output, hidden_layer_size, reg):
        r"""
        Initializes the neural network

        Parameters
        ----------
        n_input : int 
          Dimension of the model input
        n_output : int
          Number of classes to predict
        hidden_layer_size : int
          Number of neurons in the hidden layer
        reg : float
          L2 regularization strength
        """
        self.reg = reg
        # TODO Create necessary layers
        self.layers = [
            FullyConnectedLayer(n_input, hidden_layer_size),
            ReLULayer(),
            FullyConnectedLayer(hidden_layer_size, n_output),
        ]

    def compute_loss_and_gradients(self, X, y):
        r"""
        Computes total loss and updates parameter gradients
        on a batch of training examples

        Parameters
        ----------
        X : ndarray of shape(batch_size, input_features)
          Input data
        y : ndarray of shape(batch_size) of int
          Class labels
        """
        # Before running forward and backward pass through the model,
        # clear parameter gradients aggregated from the previous pass
        # TODO Set parameter gradient to zeros
        # Hint: using self.params() might be useful!

        params = self.params()
        for param_name, param in params.items():
            param.grad = np.zeros_like(param.grad)

        # TODO Compute loss and fill param gradients
        # by running forward and backward passes through the model

        last_output = self.layers[0].forward(X)
        for layer in self.layers[1:]:
            last_output = layer.forward(last_output)

        loss, d_loss = softmax_with_cross_entropy(last_output, y)

        d_next = self.layers[-1].backward(d_loss)
        for layer in self.layers[-2::-1]:
            d_next = layer.backward(d_next)

        # After that, implement l2 regularization on all params
        # Hint: self.params() is useful again!
        for param_name, param in params.items():
            reg_val, reg_grad = l2_regularization(param.value, self.reg)
            param.grad += reg_grad
            loss += reg_val
        return loss

    def predict(self, X):
        r"""
        Produces classifier predictions on the set

        Parameters
        ----------
          X : ndarray of shape(test_samples, num_features)

        Returns
        -------
          y_pred : ndarray of shape(test_samples) of int
        """
        # TODO: Implement predict
        # Hint: some of the code of the compute_loss_and_gradients
        # can be reused
        predictions = self.layers[0].forward(X)
        for layer in self.layers[1:]:
            predictions = layer.forward(predictions)

        pred = np.argmax(predictions, axis=1)
        return pred

    def params(self):
        result = {}

        # TODO Implement aggregating all of the params
        counter = 1
        for layer in self.layers:
            new_params = layer.params()
            if new_params:
                result['W_{}'.format(counter)] = new_params['W']
                result['B_{}'.format(counter)] = new_params['B']
                counter += 1
        return result

# %%
# TODO: In TwoLayerNet, implement compute_loss_and_gradients function
model = TwoLayerNet(n_input=train_X.shape[1], n_output=10, hidden_layer_size=3, reg=0)
loss = model.compute_loss_and_gradients(train_X[:2], train_y[:2])

# TODO: Now implement backward pass and aggregate all of the params
check_model_gradient(model, train_X[:2], train_y[:2])
# Out:
# Checking gradient for W_1
# Gradient check passed!
# Checking gradient for B_1
# Gradient check passed!
# Checking gradient for W_2
# Gradient check passed!
# Checking gradient for B_2
# Gradient check passed!
# True

# %% [markdown]
# Теперь добавьте к модели регуляризацию — она должна прибавляться к loss и делать свой вклад в градиенты.

# %%
# TODO: Now implement l2 regularization in the forward and backward pass
model_with_reg = TwoLayerNet(n_input = train_X.shape[1], n_output=10, hidden_layer_size=3, reg=1e1)
loss_with_reg = model_with_reg.compute_loss_and_gradients(train_X[:2], train_y[:2])
assert loss_with_reg > loss and not np.isclose(loss_with_reg, loss), \
    "Loss with regularization (%2.4f) should be higher than without it (%2.4f)!" % (loss, loss_with_reg)

check_model_gradient(model_with_reg, train_X[:2], train_y[:2])
# Out:
# Checking gradient for W_1
# Gradient check passed!
# Checking gradient for B_1
# Gradient check passed!
# Checking gradient for W_2
# Gradient check passed!
# Checking gradient for B_2
# Gradient check passed!
# True

# %% [markdown]
# Также реализуем функцию предсказания (вычисления значения) модели на новых данных.
#
# Какое значение точности мы ожидаем увидеть до начала тренировки?

# %%
def multiclass_accuracy(prediction, ground_truth):
    r"""
    Computes metrics for multiclass classification

    Parameters
    ----------
    prediction : ndarray of shape(num_samples) of int
      Model predictions
    ground_truth : ndarray of shape(num_samples) of int
      True labels

    Returns
    -------
    accuracy
      Ratio of accurate predictions to total samples
    """
    N = prediction.size
    accuracy = np.sum(prediction == ground_truth) / N
    
    return accuracy

# %%
# Finally, implement predict function!

# TODO: Implement predict function
# What would be the value we expect?
multiclass_accuracy(model_with_reg.predict(train_X[:30]), train_y[:30])
# Out:
# 0.1

# %%
model_with_reg.predict(train_X[:30])
# Out:
# array([8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8,
#        8, 8, 8, 8, 8, 8, 8, 8])

# %% [markdown]
# # Допишем код для процесса тренировки
#
# Если все реализовано корректно, значение функции ошибки должно уменьшаться с каждой эпохой, пусть и медленно. Не беспокойтесь пока про validation accuracy.

# %%
class Dataset:
    r"""
    Utility class to hold training and validation data
    """

    def __init__(self, train_X, train_y, val_X, val_y):
        self.train_X = train_X
        self.train_y = train_y
        self.val_X = val_X
        self.val_y = val_y


class Trainer:
    r"""
    Trainer of the neural network models
    Perform mini-batch SGD with the specified data, model,
    training parameters and optimization rule
    """

    def __init__(self, model, dataset, optim,
                 num_epochs=20,
                 batch_size=1000,
                 learning_rate=1e-2,
                 learning_rate_decay=1.0):
        r"""
        Initializes the trainer

        Parameters
        ----------
        model
          Neural network model
        dataset : instance of Dataset class
          Data to train on
        optim
          Optimization method
        num_epochs : int
          Number of epochs to train
        batch_size : int
        learning_rate : float
          Initial learning rate
        learning_rate_decay : float
          Ratio for decaying learning rate every epoch
        """
        self.dataset = dataset
        self.model = model
        self.optim = optim
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.num_epochs = num_epochs
        self.learning_rate_decay = learning_rate_decay

        self.optimizers = None

    def setup_optimizers(self):
        params = self.model.params()
        self.optimizers = {}
        for param_name, param in params.items():
            self.optimizers[param_name] = deepcopy(self.optim)

    def compute_accuracy(self, X, y):
        """
        Computes accuracy on provided data using mini-batches
        """
        indices = np.arange(X.shape[0])
        sections = np.arange(self.batch_size, X.shape[0], self.batch_size)
        batches_indices = np.array_split(indices, sections)

        pred = np.zeros_like(y)

        for batch_indices in batches_indices:
            batch_X = X[batch_indices]
            pred_batch = self.model.predict(batch_X)
            pred[batch_indices] = pred_batch

        return multiclass_accuracy(pred, y)

    def fit(self):
        r"""
        Trains a model
        """
        if self.optimizers is None:
            self.setup_optimizers()

        num_train = self.dataset.train_X.shape[0]

        loss_history = []
        train_acc_history = []
        val_acc_history = []
        
        for epoch in range(self.num_epochs):
            print('Started epoch {} / {}'.format(epoch, self.num_epochs))
            shuffled_indices = np.arange(num_train)
            np.random.shuffle(shuffled_indices)
            sections = np.arange(self.batch_size, num_train, self.batch_size)
            batches_indices = np.array_split(shuffled_indices, sections)

            batch_losses = []

            for batch_indices in batches_indices:
                # TODO: Generate batches based on batch_indices and
                # use model to generate loss and gradients for all the params

                X_batch = self.dataset.train_X[batch_indices]
                y_batch = self.dataset.train_y[batch_indices]

                loss = self.model.compute_loss_and_gradients(X_batch, y_batch)

                for param_name, param in self.model.params().items():
                    optimizer = self.optimizers[param_name]
                    param.value = optimizer.update(param.value, param.grad, self.learning_rate)

                batch_losses.append(loss)

            if np.not_equal(self.learning_rate_decay, 1.0):
                # TODO: Implement learning rate decay
                self.learning_rate *= self.learning_rate_decay

            ave_loss = np.mean(batch_losses)

            train_accuracy = self.compute_accuracy(self.dataset.train_X,
                                                   self.dataset.train_y)

            val_accuracy = self.compute_accuracy(self.dataset.val_X,
                                                 self.dataset.val_y)

            print("\tLoss: %f, Train accuracy: %f, val accuracy: %f" %
                  (batch_losses[-1], train_accuracy, val_accuracy))

            loss_history.append(ave_loss)
            train_acc_history.append(train_accuracy)
            val_acc_history.append(val_accuracy)

        return loss_history, train_acc_history, val_acc_history

# %%
class SGD:
    r"""
    Implements vanilla SGD update
    """
    def update(self, w, d_w, learning_rate):
        r"""
        Performs SGD update

        Parameters
        ----------
        w : ndarray
          Weights
        d_w : ndarray 
          Same shape as w — gradient
        learning_rate : float
          Learning rate

        Returns
        -------
        updated_weights : ndarray, same shape as w
        """
        return w - d_w * learning_rate


class MomentumSGD:
    r"""
    Implements Momentum SGD update
    """
    def __init__(self, momentum=0.9):
        self.momentum = momentum
        self.velocity = 0
    
    def update(self, w, d_w, learning_rate):
        r"""
        Performs Momentum SGD update

        Parameters
        ----------
        w : ndarray
          Weights
        d_w : ndarray, same shape as w
          Gradient
        learning_rate : float
          Learning rate

        Returns
        -------
        updated_weights : ndarray same shape as w
        """
        # TODO Implement momentum update
        # Hint: you'll need to introduce some variables to remember
        # velocity from the previous updates
        self.velocity = self.momentum * self.velocity - learning_rate * d_w
        return w + self.velocity

# %%
model = TwoLayerNet(n_input = train_X.shape[1], n_output=10, hidden_layer_size=100, reg=0)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, SGD(), num_epochs=20, learning_rate=1e-2)

# TODO Implement missing pieces in Trainer.fit function
# You should expect loss to go down every epoch, even if it's slow
loss_history, train_history, val_history = trainer.fit()
# Out:
# Started epoch 0 / 20
# 	Loss: 2.301263, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 1 / 20
# 	Loss: 2.299709, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 2 / 20
# 	Loss: 2.298647, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 3 / 20
# 	Loss: 2.297239, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 4 / 20
# 	Loss: 2.295726, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 5 / 20
# 	Loss: 2.295268, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 6 / 20
# 	Loss: 2.292102, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 7 / 20
# 	Loss: 2.293499, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 8 / 20
# 	Loss: 2.292320, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 9 / 20
# 	Loss: 2.289809, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 10 / 20
# 	Loss: 2.288662, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 11 / 20
# 	Loss: 2.288045, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 12 / 20
# 	Loss: 2.287139, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 13 / 20
# 	Loss: 2.284563, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 14 / 20
# 	Loss: 2.281893, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 15 / 20
# 	Loss: 2.280836, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 16 / 20
# 	Loss: 2.280108, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 17 / 20
# 	Loss: 2.277025, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 18 / 20
# 	Loss: 2.282046, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 19 / 20
# 	Loss: 2.280393, Train accuracy: 0.193222, val accuracy: 0.187000

# %%
plt.plot(loss_history)

# %%
plt.plot(train_history)
plt.plot(val_history)

# %% [markdown]
# ### Улучшаем процесс тренировки
#
# Мы реализуем несколько ключевых оптимизаций, необходимых для тренировки современных нейросетей.

# %% [markdown]
# ### Уменьшение скорости обучения (learning rate decay)
#
# Одна из необходимых оптимизаций во время тренировки нейронных сетей — постепенное уменьшение скорости обучения по мере тренировки.
#
# Один из стандартных методов — уменьшение скорости обучения (learning rate) каждые N эпох на коэффициент d (часто называемый decay). Значения N и d, как всегда, являются гиперпараметрами и должны подбираться на основе эффективности на проверочных данных (validation data).
#
# В нашем случае N будет равным 1.

# %%
# TODO Implement learning rate decay inside Trainer.fit method
# Decay should happen once per epoch

model = TwoLayerNet(n_input = train_X.shape[1], n_output=10, hidden_layer_size=100, reg=1e-1)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, SGD(), learning_rate_decay=0.99)

initial_learning_rate = trainer.learning_rate
loss_history, train_history, val_history = trainer.fit()

assert trainer.learning_rate < initial_learning_rate, "Learning rate should've been reduced"
assert trainer.learning_rate > 0.5*initial_learning_rate, "Learning rate shouldn'tve been reduced that much!"
# Out:
# Started epoch 0 / 20
# 	Loss: 2.331193, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 1 / 20
# 	Loss: 2.329046, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 2 / 20
# 	Loss: 2.327029, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 3 / 20
# 	Loss: 2.324533, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 4 / 20
# 	Loss: 2.321770, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 5 / 20
# 	Loss: 2.321109, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 6 / 20
# 	Loss: 2.318300, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 7 / 20
# 	Loss: 2.317881, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 8 / 20
# 	Loss: 2.314822, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 9 / 20
# 	Loss: 2.314494, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 10 / 20
# 	Loss: 2.313154, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 11 / 20
# 	Loss: 2.312101, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 12 / 20
# 	Loss: 2.311375, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 13 / 20
# 	Loss: 2.308891, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 14 / 20
# 	Loss: 2.308216, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 15 / 20
# 	Loss: 2.307355, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 16 / 20
# 	Loss: 2.307812, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 17 / 20
# 	Loss: 2.305520, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 18 / 20
# 	Loss: 2.301918, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 19 / 20
# 	Loss: 2.305435, Train accuracy: 0.193222, val accuracy: 0.187000

# %% [markdown]
# # Накопление импульса (Momentum SGD)
#
# Другой большой класс оптимизаций — использование более эффективных методов градиентного спуска. Мы реализуем один из них — накопление импульса (Momentum SGD).
#
# Этот метод хранит скорость движения, использует градиент для ее изменения на каждом шаге, и изменяет веса пропорционально значению скорости.
# (Физическая аналогия: Вместо скорости градиенты теперь будут задавать ускорение, но будет присутствовать сила трения.)
#
# ```
# velocity = momentum * velocity - learning_rate * gradient
# w = w + velocity
# ```
#
# `momentum` здесь коэффициент затухания, который тоже является гиперпараметром (к счастью, для него часто есть хорошее значение по умолчанию, типичный диапазон — 0.8-0.99).
#
# Несколько полезных ссылок, где метод разбирается более подробно:
# http://cs231n.github.io/neural-networks-3/#sgd
# https://distill.pub/2017/momentum/

# %%
# TODO: Implement MomentumSGD.update function in optim.py

model = TwoLayerNet(n_input = train_X.shape[1], n_output=10, hidden_layer_size=100, reg=1e-1)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, MomentumSGD(), learning_rate=1e-4, learning_rate_decay=0.99)

# You should see even better results than before!
loss_history, train_history, val_history = trainer.fit()
# Out:
# Started epoch 0 / 20
# 	Loss: 2.333546, Train accuracy: 0.080222, val accuracy: 0.065000
# Started epoch 1 / 20
# 	Loss: 2.333367, Train accuracy: 0.104444, val accuracy: 0.091000
# Started epoch 2 / 20
# 	Loss: 2.333138, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 3 / 20
# 	Loss: 2.332902, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 4 / 20
# 	Loss: 2.332708, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 5 / 20
# 	Loss: 2.332365, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 6 / 20
# 	Loss: 2.332219, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 7 / 20
# 	Loss: 2.331922, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 8 / 20
# 	Loss: 2.331894, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 9 / 20
# 	Loss: 2.331315, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 10 / 20
# 	Loss: 2.331428, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 11 / 20
# 	Loss: 2.330992, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 12 / 20
# 	Loss: 2.330926, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 13 / 20
# 	Loss: 2.330226, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 14 / 20
# 	Loss: 2.330432, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 15 / 20
# 	Loss: 2.330288, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 16 / 20
# 	Loss: 2.330440, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 17 / 20
# 	Loss: 2.329727, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 18 / 20
# 	Loss: 2.329467, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 19 / 20
# 	Loss: 2.329264, Train accuracy: 0.193222, val accuracy: 0.187000

# %% [markdown]
# ### Ну что, давайте уже тренировать сеть!

# %% [markdown]
# ### Финальный тест — переобучимся (overfit) на маленьком наборе данных
#
# Хороший способ проверить, все ли реализовано корректно — переобучить сеть на маленьком наборе данных.
# Наша модель обладает достаточной мощностью, чтобы приблизить маленький набор данных идеально, поэтому мы ожидаем, что на нем мы быстро дойдем до 100% точности на тренировочном наборе.
#
# Если этого не происходит, то где-то была допущена ошибка!

# %%
data_size = 15
model = TwoLayerNet(n_input = train_X.shape[1], n_output=10, hidden_layer_size=100, reg=1e-1)
dataset = Dataset(train_X[:data_size], train_y[:data_size], val_X[:data_size], val_y[:data_size])
trainer = Trainer(model, dataset, SGD(), learning_rate=1e-1, num_epochs=150, batch_size=5)

# You should expect this to reach 1.0 training accuracy 
loss_history, train_history, val_history = trainer.fit()
# Out:
# Started epoch 0 / 150
# 	Loss: 2.327862, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 1 / 150
# 	Loss: 2.312831, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 2 / 150
# 	Loss: 2.319310, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 3 / 150
# 	Loss: 2.281761, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 4 / 150
# 	Loss: 2.340438, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 5 / 150
# 	Loss: 2.319203, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 6 / 150
# 	Loss: 2.339462, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 7 / 150
# 	Loss: 2.176484, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 8 / 150
# 	Loss: 2.231060, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 9 / 150
# 	Loss: 1.945524, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 10 / 150
# 	Loss: 2.130711, Train accuracy: 0.333333, val accuracy: 0.200000
# Started epoch 11 / 150
# 	Loss: 1.900093, Train accuracy: 0.400000, val accuracy: 0.200000
# Started epoch 12 / 150
# 	Loss: 1.757821, Train accuracy: 0.400000, val accuracy: 0.133333
# Started epoch 13 / 150
# 	Loss: 2.110799, Train accuracy: 0.400000, val accuracy: 0.133333
# Started epoch 14 / 150
# 	Loss: 1.540570, Train accuracy: 0.400000, val accuracy: 0.133333
# Started epoch 15 / 150
# 	Loss: 2.500404, Train accuracy: 0.400000, val accuracy: 0.133333
# Started epoch 16 / 150
# 	Loss: 2.237191, Train accuracy: 0.400000, val accuracy: 0.133333
# Started epoch 17 / 150
# 	Loss: 1.626154, Train accuracy: 0.466667, val accuracy: 0.133333
# Started epoch 18 / 150
# 	Loss: 1.170563, Train accuracy: 0.466667, val accuracy: 0.133333
# Started epoch 19 / 150
# 	Loss: 2.177770, Train accuracy: 0.466667, val accuracy: 0.133333
# Started epoch 20 / 150
# 	Loss: 1.910026, Train accuracy: 0.466667, val accuracy: 0.133333
# Started epoch 21 / 150
# 	Loss: 2.172213, Train accuracy: 0.466667, val accuracy: 0.133333
# Started epoch 22 / 150
# 	Loss: 2.123710, Train accuracy: 0.466667, val accuracy: 0.133333
# Started epoch 23 / 150
# 	Loss: 1.875097, Train accuracy: 0.466667, val accuracy: 0.133333
# Started epoch 24 / 150
# 	Loss: 1.681855, Train accuracy: 0.466667, val accuracy: 0.133333
# Started epoch 25 / 150
# 	Loss: 1.981846, Train accuracy: 0.466667, val accuracy: 0.133333
# Started epoch 26 / 150
# 	Loss: 1.231572, Train accuracy: 0.466667, val accuracy: 0.200000
# Started epoch 27 / 150
# 	Loss: 1.338212, Train accuracy: 0.466667, val accuracy: 0.200000
# Started epoch 28 / 150
# 	Loss: 1.334539, Train accuracy: 0.466667, val accuracy: 0.200000
# Started epoch 29 / 150
# 	Loss: 1.526871, Train accuracy: 0.533333, val accuracy: 0.200000
# Started epoch 30 / 150
# 	Loss: 1.444604, Train accuracy: 0.600000, val accuracy: 0.200000
# Started epoch 31 / 150
# 	Loss: 1.362002, Train accuracy: 0.600000, val accuracy: 0.200000
# Started epoch 32 / 150
# 	Loss: 2.203457, Train accuracy: 0.733333, val accuracy: 0.200000
# Started epoch 33 / 150
# 	Loss: 1.521467, Train accuracy: 0.666667, val accuracy: 0.200000
# Started epoch 34 / 150
# 	Loss: 1.471627, Train accuracy: 0.600000, val accuracy: 0.200000
# Started epoch 35 / 150
# 	Loss: 1.262739, Train accuracy: 0.600000, val accuracy: 0.200000
# Started epoch 36 / 150
# 	Loss: 0.994345, Train accuracy: 0.600000, val accuracy: 0.200000
# Started epoch 37 / 150
# 	Loss: 1.129039, Train accuracy: 0.600000, val accuracy: 0.200000
# Started epoch 38 / 150
# 	Loss: 1.736005, Train accuracy: 0.733333, val accuracy: 0.200000
# Started epoch 39 / 150
# 	Loss: 1.802961, Train accuracy: 0.733333, val accuracy: 0.200000
# Started epoch 40 / 150
# 	Loss: 1.626827, Train accuracy: 0.666667, val accuracy: 0.200000
# Started epoch 41 / 150
# 	Loss: 1.734375, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 42 / 150
# 	Loss: 1.345604, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 43 / 150
# 	Loss: 1.745988, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 44 / 150
# 	Loss: 1.413046, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 45 / 150
# 	Loss: 1.456266, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 46 / 150
# 	Loss: 1.389779, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 47 / 150
# 	Loss: 1.503571, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 48 / 150
# 	Loss: 1.304228, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 49 / 150
# 	Loss: 1.290633, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 50 / 150
# 	Loss: 1.376897, Train accuracy: 0.666667, val accuracy: 0.200000
# Started epoch 51 / 150
# 	Loss: 1.778026, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 52 / 150
# 	Loss: 1.536747, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 53 / 150
# 	Loss: 2.105304, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 54 / 150
# 	Loss: 1.717626, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 55 / 150
# 	Loss: 1.312945, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 56 / 150
# 	Loss: 1.001675, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 57 / 150
# 	Loss: 1.005182, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 58 / 150
# 	Loss: 1.634680, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 59 / 150
# 	Loss: 1.021799, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 60 / 150
# 	Loss: 1.731195, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 61 / 150
# 	Loss: 1.077354, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 62 / 150
# 	Loss: 1.041346, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 63 / 150
# 	Loss: 1.316205, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 64 / 150
# 	Loss: 1.365494, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 65 / 150
# 	Loss: 0.950221, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 66 / 150
# 	Loss: 1.346325, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 67 / 150
# 	Loss: 1.041833, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 68 / 150
# 	Loss: 1.584535, Train accuracy: 0.866667, val accuracy: 0.200000
# Started epoch 69 / 150
# 	Loss: 1.354346, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 70 / 150
# 	Loss: 1.443983, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 71 / 150
# 	Loss: 1.467755, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 72 / 150
# 	Loss: 1.702592, Train accuracy: 0.866667, val accuracy: 0.200000
# Started epoch 73 / 150
# 	Loss: 1.060446, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 74 / 150
# 	Loss: 1.349026, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 75 / 150
# 	Loss: 1.655015, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 76 / 150
# 	Loss: 1.461500, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 77 / 150
# 	Loss: 1.246473, Train accuracy: 0.866667, val accuracy: 0.200000
# Started epoch 78 / 150
# 	Loss: 0.990333, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 79 / 150
# 	Loss: 1.596859, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 80 / 150
# 	Loss: 1.346682, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 81 / 150
# 	Loss: 1.643457, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 82 / 150
# 	Loss: 1.607573, Train accuracy: 0.866667, val accuracy: 0.200000
# Started epoch 83 / 150
# 	Loss: 1.765774, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 84 / 150
# 	Loss: 1.133073, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 85 / 150
# 	Loss: 1.648404, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 86 / 150
# 	Loss: 1.155610, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 87 / 150
# 	Loss: 1.093363, Train accuracy: 0.866667, val accuracy: 0.200000
# Started epoch 88 / 150
# 	Loss: 1.009628, Train accuracy: 0.866667, val accuracy: 0.200000
# Started epoch 89 / 150
# 	Loss: 1.222361, Train accuracy: 0.866667, val accuracy: 0.200000
# Started epoch 90 / 150
# 	Loss: 1.229182, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 91 / 150
# 	Loss: 1.263443, Train accuracy: 0.866667, val accuracy: 0.200000
# Started epoch 92 / 150
# 	Loss: 1.443824, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 93 / 150
# 	Loss: 1.294767, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 94 / 150
# 	Loss: 1.502768, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 95 / 150
# 	Loss: 1.211571, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 96 / 150
# 	Loss: 0.953149, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 97 / 150
# 	Loss: 1.708824, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 98 / 150
# 	Loss: 1.408219, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 99 / 150
# 	Loss: 1.220649, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 100 / 150
# 	Loss: 1.376782, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 101 / 150
# 	Loss: 1.356982, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 102 / 150
# 	Loss: 1.666348, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 103 / 150
# 	Loss: 1.580462, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 104 / 150
# 	Loss: 1.203810, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 105 / 150
# 	Loss: 1.335288, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 106 / 150
# 	Loss: 1.430377, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 107 / 150
# 	Loss: 1.238541, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 108 / 150
# 	Loss: 1.597558, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 109 / 150
# 	Loss: 1.422898, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 110 / 150
# 	Loss: 1.331374, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 111 / 150
# 	Loss: 1.544535, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 112 / 150
# 	Loss: 1.147564, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 113 / 150
# 	Loss: 1.379976, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 114 / 150
# 	Loss: 1.430951, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 115 / 150
# 	Loss: 1.330780, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 116 / 150
# 	Loss: 1.435013, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 117 / 150
# 	Loss: 1.179235, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 118 / 150
# 	Loss: 1.446036, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 119 / 150
# 	Loss: 1.630166, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 120 / 150
# 	Loss: 1.164090, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 121 / 150
# 	Loss: 1.372794, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 122 / 150
# 	Loss: 1.119825, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 123 / 150
# 	Loss: 1.405383, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 124 / 150
# 	Loss: 1.341748, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 125 / 150
# 	Loss: 1.208828, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 126 / 150
# 	Loss: 1.333930, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 127 / 150
# 	Loss: 1.188108, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 128 / 150
# 	Loss: 1.227060, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 129 / 150
# 	Loss: 1.651075, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 130 / 150
# 	Loss: 1.348304, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 131 / 150
# 	Loss: 1.361354, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 132 / 150
# 	Loss: 1.133536, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 133 / 150
# 	Loss: 1.189681, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 134 / 150
# 	Loss: 1.481212, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 135 / 150
# 	Loss: 1.393608, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 136 / 150
# 	Loss: 1.182148, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 137 / 150
# 	Loss: 1.554198, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 138 / 150
# 	Loss: 1.539649, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 139 / 150
# 	Loss: 1.129508, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 140 / 150
# 	Loss: 1.418602, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 141 / 150
# 	Loss: 1.460570, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 142 / 150
# 	Loss: 1.419882, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 143 / 150
# 	Loss: 1.443267, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 144 / 150
# 	Loss: 1.280438, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 145 / 150
# 	Loss: 1.374449, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 146 / 150
# 	Loss: 1.236767, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 147 / 150
# 	Loss: 1.325438, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 148 / 150
# 	Loss: 1.402180, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 149 / 150
# 	Loss: 1.157657, Train accuracy: 1.000000, val accuracy: 0.200000

# %%
plt.plot(loss_history)

# %%
plt.plot(train_history)
plt.plot(val_history)

# %% [markdown]
# Теперь найдем гипепараметры, для которых этот процесс сходится быстрее.
# Если все реализовано корректно, то существуют параметры, при которых процесс сходится в **20** эпох или еще быстрее.

# %%
# Now, tweak some hyper parameters and make it train to 1.0 accuracy in 20 epochs or less

model = TwoLayerNet(n_input = train_X.shape[1], n_output=10, hidden_layer_size=200, reg = 0.01)
dataset = Dataset(train_X[:data_size], train_y[:data_size], val_X[:data_size], val_y[:data_size])
# DONE: Change any hyperparamers or optimizators to reach training accuracy in 20 epochs
trainer = Trainer(model, dataset, MomentumSGD(momentum=0.9), learning_rate=1e-1, num_epochs=20, batch_size=5)

loss_history, train_history, val_history = trainer.fit()
# Out:
# Started epoch 0 / 20
# 	Loss: 2.314706, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 1 / 20
# 	Loss: 2.232818, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 2 / 20
# 	Loss: 2.199285, Train accuracy: 0.266667, val accuracy: 0.133333
# Started epoch 3 / 20
# 	Loss: 2.417638, Train accuracy: 0.333333, val accuracy: 0.133333
# Started epoch 4 / 20
# 	Loss: 1.782753, Train accuracy: 0.400000, val accuracy: 0.133333
# Started epoch 5 / 20
# 	Loss: 1.710557, Train accuracy: 0.466667, val accuracy: 0.133333
# Started epoch 6 / 20
# 	Loss: 1.343691, Train accuracy: 0.533333, val accuracy: 0.133333
# Started epoch 7 / 20
# 	Loss: 0.963991, Train accuracy: 0.600000, val accuracy: 0.200000
# Started epoch 8 / 20
# 	Loss: 0.872976, Train accuracy: 0.733333, val accuracy: 0.133333
# Started epoch 9 / 20
# 	Loss: 1.640562, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 10 / 20
# 	Loss: 0.598284, Train accuracy: 0.800000, val accuracy: 0.200000
# Started epoch 11 / 20
# 	Loss: 0.669417, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 12 / 20
# 	Loss: 1.043223, Train accuracy: 0.800000, val accuracy: 0.133333
# Started epoch 13 / 20
# 	Loss: 0.581169, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 14 / 20
# 	Loss: 0.389104, Train accuracy: 0.866667, val accuracy: 0.200000
# Started epoch 15 / 20
# 	Loss: 0.618763, Train accuracy: 1.000000, val accuracy: 0.200000
# Started epoch 16 / 20
# 	Loss: 0.772870, Train accuracy: 0.933333, val accuracy: 0.200000
# Started epoch 17 / 20
# 	Loss: 0.654204, Train accuracy: 0.866667, val accuracy: 0.200000
# Started epoch 18 / 20
# 	Loss: 0.565299, Train accuracy: 0.866667, val accuracy: 0.133333
# Started epoch 19 / 20
# 	Loss: 0.570515, Train accuracy: 1.000000, val accuracy: 0.200000

# %%
plt.plot(loss_history)

# %% [markdown]
# # Итак, основное мероприятие!
#
# Натренируйте лучшую нейросеть! Можно добавлять и изменять параметры, менять количество нейронов в слоях сети и как угодно экспериментировать.
#
# Можно добиться точности лучше **60%** на validation set.

# %%
# Let's train the best one-hidden-layer network we can

learning_rates = 1e-2
reg_strength = 1e-3
learning_rate_decay = 0.999
hidden_layer_size = 200
num_epochs = 100
batch_size = 1000

params_list = [
    {'learning_rate': 1e-4, 'reg_strength': 1e-3, 'learning_rate_decay': 0.999},
    {'learning_rate': 1e-4, 'reg_strength': 1e-1, 'learning_rate_decay': 0.999},
    {'learning_rate': 1e-2, 'reg_strength': 1e-3, 'learning_rate_decay': 0.999},
    {'learning_rate': 1e-4, 'reg_strength': 1e-3, 'learning_rate_decay': 0},
    {'learning_rate': 1e-3, 'reg_strength': 1e-2, 'learning_rate_decay': 0.999},
    {'learning_rate': 1e-1, 'reg_strength': 1e-2, 'learning_rate_decay': 0.9},
]

best_classifier = None
best_val_accuracy = None

loss_history = []
train_history = []
val_history = []

# TODO find the best hyperparameters to train the network
# Don't hesitate to add new values to the arrays above, perform experiments, use any tricks you want
# You should expect to get to at least 40% of valudation accuracy
# Save loss/train/history of the best classifier to the variables above
dataset = Dataset(train_X, train_y, val_X, val_y)
best_classifier_history = None
best_params = None
best_trainer = None

for param in params_list:
    print('\nStarted learning with new params\n')
    current_lr = param['learning_rate']
    current_reg_str = param['reg_strength']
    current_lr_decay = param['learning_rate_decay']

    model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = hidden_layer_size, reg = current_reg_str)
    trainer = Trainer(model, dataset, MomentumSGD(momentum=0.9), learning_rate=current_lr, num_epochs=num_epochs,
                    batch_size=batch_size, learning_rate_decay=current_lr_decay)

    loss_history, train_history, val_history = trainer.fit()
    
    if best_val_accuracy is None:
        best_val_accuracy = max(val_history)
        best_classifier = model
        best_classifier_history = (loss_history, train_history, val_history)
        best_params = param
        best_trainer = trainer
        print('\nFirst best_val_accuracy: {}'.format(best_val_accuracy))
        print('Params init {}'.format(param))
        
    else:
        if max(val_history) > best_val_accuracy:
            best_val_accuracy = max(val_history)
            best_classifier = model
            best_classifier_history = (loss_history, train_history, val_history)
            best_params = param
            best_trainer = trainer
            print('\nNew best_val_accuracy: {}'.format(best_val_accuracy))
            print('New params: {}'.format(param))

print('\nContinue training best model with params: {}\n'.format(best_params))
loss_history, train_history, val_history = best_trainer.fit()

best_classifier_history[0].extend(loss_history)
best_classifier_history[1].extend(train_history)
best_classifier_history[2].extend(val_history)

best_val_accuracy = max(best_classifier_history[2])

print('\nbest validation accuracy achieved: %f' % best_val_accuracy)
# Out:
# Started learning with new params
#
# Started epoch 0 / 100
# 	Loss: 2.303304, Train accuracy: 0.065778, val accuracy: 0.069000
# Started epoch 1 / 100
# 	Loss: 2.303282, Train accuracy: 0.135667, val accuracy: 0.150000
# Started epoch 2 / 100
# 	Loss: 2.303115, Train accuracy: 0.142333, val accuracy: 0.157000
# Started epoch 3 / 100
# 	Loss: 2.303013, Train accuracy: 0.142333, val accuracy: 0.157000
# Started epoch 4 / 100
# 	Loss: 2.302853, Train accuracy: 0.142333, val accuracy: 0.157000
# Started epoch 5 / 100
# 	Loss: 2.302735, Train accuracy: 0.142556, val accuracy: 0.157000
# Started epoch 6 / 100
# 	Loss: 2.302457, Train accuracy: 0.176444, val accuracy: 0.168000
# Started epoch 7 / 100
# 	Loss: 2.302429, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 8 / 100
# 	Loss: 2.302369, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 9 / 100
# 	Loss: 2.302199, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 10 / 100
# 	Loss: 2.302089, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 11 / 100
# 	Loss: 2.302035, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 12 / 100
# 	Loss: 2.301620, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 13 / 100
# 	Loss: 2.301661, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 14 / 100
# 	Loss: 2.301221, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 15 / 100
# 	Loss: 2.301600, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 16 / 100
# 	Loss: 2.301503, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 17 / 100
# 	Loss: 2.300778, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 18 / 100
# 	Loss: 2.300807, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 19 / 100
# 	Loss: 2.300989, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 20 / 100
# 	Loss: 2.300829, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 21 / 100
# 	Loss: 2.300352, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 22 / 100
# 	Loss: 2.300560, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 23 / 100
# 	Loss: 2.300094, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 24 / 100
# 	Loss: 2.300238, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 25 / 100
# 	Loss: 2.299486, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 26 / 100
# 	Loss: 2.299657, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 27 / 100
# 	Loss: 2.300231, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 28 / 100
# 	Loss: 2.299455, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 29 / 100
# 	Loss: 2.298701, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 30 / 100
# 	Loss: 2.299317, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 31 / 100
# 	Loss: 2.299074, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 32 / 100
# 	Loss: 2.299187, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 33 / 100
# 	Loss: 2.298816, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 34 / 100
# 	Loss: 2.298898, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 35 / 100
# 	Loss: 2.298247, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 36 / 100
# 	Loss: 2.298640, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 37 / 100
# 	Loss: 2.298621, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 38 / 100
# 	Loss: 2.298040, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 39 / 100
# 	Loss: 2.297872, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 40 / 100
# 	Loss: 2.298974, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 41 / 100
# 	Loss: 2.297637, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 42 / 100
# 	Loss: 2.298542, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 43 / 100
# 	Loss: 2.298465, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 44 / 100
# 	Loss: 2.296741, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 45 / 100
# 	Loss: 2.296724, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 46 / 100
# 	Loss: 2.296990, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 47 / 100
# 	Loss: 2.297481, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 48 / 100
# 	Loss: 2.297745, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 49 / 100
# 	Loss: 2.297434, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 50 / 100
# 	Loss: 2.297052, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 51 / 100
# 	Loss: 2.296522, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 52 / 100
# 	Loss: 2.297359, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 53 / 100
# 	Loss: 2.296653, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 54 / 100
# 	Loss: 2.296805, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 55 / 100
# 	Loss: 2.296574, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 56 / 100
# 	Loss: 2.297782, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 57 / 100
# 	Loss: 2.296666, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 58 / 100
# 	Loss: 2.296105, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 59 / 100
# 	Loss: 2.296915, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 60 / 100
# 	Loss: 2.295769, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 61 / 100
# 	Loss: 2.294625, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 62 / 100
# 	Loss: 2.296339, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 63 / 100
# 	Loss: 2.294503, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 64 / 100
# 	Loss: 2.296873, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 65 / 100
# 	Loss: 2.295917, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 66 / 100
# 	Loss: 2.294558, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 67 / 100
# 	Loss: 2.294110, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 68 / 100
# 	Loss: 2.295196, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 69 / 100
# 	Loss: 2.294308, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 70 / 100
# 	Loss: 2.293949, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 71 / 100
# 	Loss: 2.294900, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 72 / 100
# 	Loss: 2.295177, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 73 / 100
# 	Loss: 2.294099, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 74 / 100
# 	Loss: 2.294921, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 75 / 100
# 	Loss: 2.292777, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 76 / 100
# 	Loss: 2.293879, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 77 / 100
# 	Loss: 2.293898, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 78 / 100
# 	Loss: 2.294392, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 79 / 100
# 	Loss: 2.293798, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 80 / 100
# 	Loss: 2.293764, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 81 / 100
# 	Loss: 2.292604, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 82 / 100
# 	Loss: 2.294798, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 83 / 100
# 	Loss: 2.294325, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 84 / 100
# 	Loss: 2.294194, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 85 / 100
# 	Loss: 2.291756, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 86 / 100
# 	Loss: 2.292801, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 87 / 100
# 	Loss: 2.291889, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 88 / 100
# 	Loss: 2.291863, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 89 / 100
# 	Loss: 2.291245, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 90 / 100
# 	Loss: 2.291481, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 91 / 100
# 	Loss: 2.291781, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 92 / 100
# 	Loss: 2.292537, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 93 / 100
# 	Loss: 2.291061, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 94 / 100
# 	Loss: 2.294963, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 95 / 100
# 	Loss: 2.292004, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 96 / 100
# 	Loss: 2.291364, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 97 / 100
# 	Loss: 2.290107, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 98 / 100
# 	Loss: 2.291603, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 99 / 100
# 	Loss: 2.292056, Train accuracy: 0.193222, val accuracy: 0.187000
#
# First best_val_accuracy: 0.187
# Params init {'learning_rate': 0.0001, 'reg_strength': 0.001, 'learning_rate_decay': 0.999}
#
# Started learning with new params
#
# Started epoch 0 / 100
# 	Loss: 2.363944, Train accuracy: 0.160000, val accuracy: 0.155000
# Started epoch 1 / 100
# 	Loss: 2.363600, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 2 / 100
# 	Loss: 2.363340, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 3 / 100
# 	Loss: 2.362909, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 4 / 100
# 	Loss: 2.362476, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 5 / 100
# 	Loss: 2.362317, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 6 / 100
# 	Loss: 2.361828, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 7 / 100
# 	Loss: 2.361587, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 8 / 100
# 	Loss: 2.361192, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 9 / 100
# 	Loss: 2.360775, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 10 / 100
# 	Loss: 2.360687, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 11 / 100
# 	Loss: 2.359974, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 12 / 100
# 	Loss: 2.360019, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 13 / 100
# 	Loss: 2.359647, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 14 / 100
# 	Loss: 2.359162, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 15 / 100
# 	Loss: 2.358733, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 16 / 100
# 	Loss: 2.358507, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 17 / 100
# 	Loss: 2.358195, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 18 / 100
# 	Loss: 2.357819, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 19 / 100
# 	Loss: 2.357151, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 20 / 100
# 	Loss: 2.357266, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 21 / 100
# 	Loss: 2.356942, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 22 / 100
# 	Loss: 2.357076, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 23 / 100
# 	Loss: 2.356397, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 24 / 100
# 	Loss: 2.355985, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 25 / 100
# 	Loss: 2.354925, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 26 / 100
# 	Loss: 2.355348, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 27 / 100
# 	Loss: 2.354346, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 28 / 100
# 	Loss: 2.354724, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 29 / 100
# 	Loss: 2.354501, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 30 / 100
# 	Loss: 2.354258, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 31 / 100
# 	Loss: 2.353032, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 32 / 100
# 	Loss: 2.353404, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 33 / 100
# 	Loss: 2.352951, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 34 / 100
# 	Loss: 2.352494, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 35 / 100
# 	Loss: 2.352310, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 36 / 100
# 	Loss: 2.351411, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 37 / 100
# 	Loss: 2.352023, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 38 / 100
# 	Loss: 2.351592, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 39 / 100
# 	Loss: 2.351540, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 40 / 100
# 	Loss: 2.350625, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 41 / 100
# 	Loss: 2.350846, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 42 / 100
# 	Loss: 2.350757, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 43 / 100
# 	Loss: 2.349711, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 44 / 100
# 	Loss: 2.350123, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 45 / 100
# 	Loss: 2.349269, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 46 / 100
# 	Loss: 2.349603, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 47 / 100
# 	Loss: 2.348348, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 48 / 100
# 	Loss: 2.349486, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 49 / 100
# 	Loss: 2.348478, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 50 / 100
# 	Loss: 2.348187, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 51 / 100
# 	Loss: 2.348070, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 52 / 100
# 	Loss: 2.348041, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 53 / 100
# 	Loss: 2.346625, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 54 / 100
# 	Loss: 2.347338, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 55 / 100
# 	Loss: 2.346638, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 56 / 100
# 	Loss: 2.346771, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 57 / 100
# 	Loss: 2.347162, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 58 / 100
# 	Loss: 2.346095, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 59 / 100
# 	Loss: 2.345845, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 60 / 100
# 	Loss: 2.344888, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 61 / 100
# 	Loss: 2.345279, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 62 / 100
# 	Loss: 2.344981, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 63 / 100
# 	Loss: 2.342998, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 64 / 100
# 	Loss: 2.342656, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 65 / 100
# 	Loss: 2.345479, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 66 / 100
# 	Loss: 2.344388, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 67 / 100
# 	Loss: 2.344121, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 68 / 100
# 	Loss: 2.342151, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 69 / 100
# 	Loss: 2.343085, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 70 / 100
# 	Loss: 2.344458, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 71 / 100
# 	Loss: 2.341657, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 72 / 100
# 	Loss: 2.342543, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 73 / 100
# 	Loss: 2.341863, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 74 / 100
# 	Loss: 2.341752, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 75 / 100
# 	Loss: 2.340991, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 76 / 100
# 	Loss: 2.340736, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 77 / 100
# 	Loss: 2.340695, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 78 / 100
# 	Loss: 2.341725, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 79 / 100
# 	Loss: 2.339845, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 80 / 100
# 	Loss: 2.340641, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 81 / 100
# 	Loss: 2.339407, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 82 / 100
# 	Loss: 2.340774, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 83 / 100
# 	Loss: 2.339596, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 84 / 100
# 	Loss: 2.339017, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 85 / 100
# 	Loss: 2.339646, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 86 / 100
# 	Loss: 2.339669, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 87 / 100
# 	Loss: 2.338365, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 88 / 100
# 	Loss: 2.340285, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 89 / 100
# 	Loss: 2.337344, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 90 / 100
# 	Loss: 2.337320, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 91 / 100
# 	Loss: 2.338526, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 92 / 100
# 	Loss: 2.337869, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 93 / 100
# 	Loss: 2.337572, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 94 / 100
# 	Loss: 2.337429, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 95 / 100
# 	Loss: 2.338855, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 96 / 100
# 	Loss: 2.335942, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 97 / 100
# 	Loss: 2.337242, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 98 / 100
# 	Loss: 2.336069, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 99 / 100
# 	Loss: 2.335741, Train accuracy: 0.193222, val accuracy: 0.187000
#
# Started learning with new params
#
# Started epoch 0 / 100
# 	Loss: 2.298390, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 1 / 100
# 	Loss: 2.289685, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 2 / 100
# 	Loss: 2.277705, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 3 / 100
# 	Loss: 2.264427, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 4 / 100
# 	Loss: 2.262087, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 5 / 100
# 	Loss: 2.264297, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 6 / 100
# 	Loss: 2.254538, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 7 / 100
# 	Loss: 2.250251, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 8 / 100
# 	Loss: 2.248467, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 9 / 100
# 	Loss: 2.238656, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 10 / 100
# 	Loss: 2.234224, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 11 / 100
# 	Loss: 2.229278, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 12 / 100
# 	Loss: 2.231828, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 13 / 100
# 	Loss: 2.236336, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 14 / 100
# 	Loss: 2.250696, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 15 / 100
# 	Loss: 2.233844, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 16 / 100
# 	Loss: 2.235078, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 17 / 100
# 	Loss: 2.237250, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 18 / 100
# 	Loss: 2.220362, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 19 / 100
# 	Loss: 2.229843, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 20 / 100
# 	Loss: 2.237999, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 21 / 100
# 	Loss: 2.223009, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 22 / 100
# 	Loss: 2.239806, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 23 / 100
# 	Loss: 2.228544, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 24 / 100
# 	Loss: 2.246104, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 25 / 100
# 	Loss: 2.229433, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 26 / 100
# 	Loss: 2.228929, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 27 / 100
# 	Loss: 2.230124, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 28 / 100
# 	Loss: 2.237518, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 29 / 100
# 	Loss: 2.230967, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 30 / 100
# 	Loss: 2.238342, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 31 / 100
# 	Loss: 2.230591, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 32 / 100
# 	Loss: 2.220501, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 33 / 100
# 	Loss: 2.224833, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 34 / 100
# 	Loss: 2.215430, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 35 / 100
# 	Loss: 2.233670, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 36 / 100
# 	Loss: 2.205904, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 37 / 100
# 	Loss: 2.204325, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 38 / 100
# 	Loss: 2.205139, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 39 / 100
# 	Loss: 2.182447, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 40 / 100
# 	Loss: 2.213992, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 41 / 100
# 	Loss: 2.218759, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 42 / 100
# 	Loss: 2.193502, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 43 / 100
# 	Loss: 2.193761, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 44 / 100
# 	Loss: 2.177807, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 45 / 100
# 	Loss: 2.176006, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 46 / 100
# 	Loss: 2.157927, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 47 / 100
# 	Loss: 2.168842, Train accuracy: 0.194000, val accuracy: 0.187000
# Started epoch 48 / 100
# 	Loss: 2.129191, Train accuracy: 0.197556, val accuracy: 0.192000
# Started epoch 49 / 100
# 	Loss: 2.160072, Train accuracy: 0.204222, val accuracy: 0.200000
# Started epoch 50 / 100
# 	Loss: 2.137581, Train accuracy: 0.208667, val accuracy: 0.207000
# Started epoch 51 / 100
# 	Loss: 2.128253, Train accuracy: 0.214000, val accuracy: 0.208000
# Started epoch 52 / 100
# 	Loss: 2.142083, Train accuracy: 0.217222, val accuracy: 0.212000
# Started epoch 53 / 100
# 	Loss: 2.131809, Train accuracy: 0.221333, val accuracy: 0.219000
# Started epoch 54 / 100
# 	Loss: 2.093024, Train accuracy: 0.226778, val accuracy: 0.221000
# Started epoch 55 / 100
# 	Loss: 2.131288, Train accuracy: 0.230667, val accuracy: 0.228000
# Started epoch 56 / 100
# 	Loss: 2.115649, Train accuracy: 0.233444, val accuracy: 0.231000
# Started epoch 57 / 100
# 	Loss: 2.115403, Train accuracy: 0.235444, val accuracy: 0.233000
# Started epoch 58 / 100
# 	Loss: 2.084571, Train accuracy: 0.239556, val accuracy: 0.237000
# Started epoch 59 / 100
# 	Loss: 2.111694, Train accuracy: 0.243111, val accuracy: 0.243000
# Started epoch 60 / 100
# 	Loss: 2.082342, Train accuracy: 0.245778, val accuracy: 0.246000
# Started epoch 61 / 100
# 	Loss: 2.091785, Train accuracy: 0.249667, val accuracy: 0.250000
# Started epoch 62 / 100
# 	Loss: 2.095939, Train accuracy: 0.254556, val accuracy: 0.252000
# Started epoch 63 / 100
# 	Loss: 2.056255, Train accuracy: 0.256778, val accuracy: 0.258000
# Started epoch 64 / 100
# 	Loss: 2.083604, Train accuracy: 0.258556, val accuracy: 0.259000
# Started epoch 65 / 100
# 	Loss: 2.041386, Train accuracy: 0.262667, val accuracy: 0.261000
# Started epoch 66 / 100
# 	Loss: 2.079729, Train accuracy: 0.266333, val accuracy: 0.267000
# Started epoch 67 / 100
# 	Loss: 2.012922, Train accuracy: 0.270556, val accuracy: 0.265000
# Started epoch 68 / 100
# 	Loss: 2.064447, Train accuracy: 0.272556, val accuracy: 0.270000
# Started epoch 69 / 100
# 	Loss: 2.021580, Train accuracy: 0.279333, val accuracy: 0.279000
# Started epoch 70 / 100
# 	Loss: 2.022025, Train accuracy: 0.283111, val accuracy: 0.281000
# Started epoch 71 / 100
# 	Loss: 1.997926, Train accuracy: 0.288556, val accuracy: 0.288000
# Started epoch 72 / 100
# 	Loss: 1.987433, Train accuracy: 0.294778, val accuracy: 0.291000
# Started epoch 73 / 100
# 	Loss: 1.973942, Train accuracy: 0.299667, val accuracy: 0.298000
# Started epoch 74 / 100
# 	Loss: 1.973322, Train accuracy: 0.305000, val accuracy: 0.300000
# Started epoch 75 / 100
# 	Loss: 1.979302, Train accuracy: 0.307444, val accuracy: 0.310000
# Started epoch 76 / 100
# 	Loss: 1.889093, Train accuracy: 0.314889, val accuracy: 0.308000
# Started epoch 77 / 100
# 	Loss: 1.966419, Train accuracy: 0.319556, val accuracy: 0.309000
# Started epoch 78 / 100
# 	Loss: 1.932496, Train accuracy: 0.324667, val accuracy: 0.317000
# Started epoch 79 / 100
# 	Loss: 1.956800, Train accuracy: 0.330778, val accuracy: 0.319000
# Started epoch 80 / 100
# 	Loss: 1.916688, Train accuracy: 0.340333, val accuracy: 0.327000
# Started epoch 81 / 100
# 	Loss: 1.893913, Train accuracy: 0.348444, val accuracy: 0.329000
# Started epoch 82 / 100
# 	Loss: 1.837605, Train accuracy: 0.359333, val accuracy: 0.333000
# Started epoch 83 / 100
# 	Loss: 1.883778, Train accuracy: 0.365889, val accuracy: 0.338000
# Started epoch 84 / 100
# 	Loss: 1.859587, Train accuracy: 0.375444, val accuracy: 0.344000
# Started epoch 85 / 100
# 	Loss: 1.839641, Train accuracy: 0.381556, val accuracy: 0.350000
# Started epoch 86 / 100
# 	Loss: 1.813491, Train accuracy: 0.389111, val accuracy: 0.357000
# Started epoch 87 / 100
# 	Loss: 1.849957, Train accuracy: 0.393667, val accuracy: 0.364000
# Started epoch 88 / 100
# 	Loss: 1.762478, Train accuracy: 0.400333, val accuracy: 0.371000
# Started epoch 89 / 100
# 	Loss: 1.772795, Train accuracy: 0.405889, val accuracy: 0.379000
# Started epoch 90 / 100
# 	Loss: 1.789706, Train accuracy: 0.412778, val accuracy: 0.388000
# Started epoch 91 / 100
# 	Loss: 1.744262, Train accuracy: 0.419111, val accuracy: 0.395000
# Started epoch 92 / 100
# 	Loss: 1.726705, Train accuracy: 0.424667, val accuracy: 0.400000
# Started epoch 93 / 100
# 	Loss: 1.739769, Train accuracy: 0.430667, val accuracy: 0.407000
# Started epoch 94 / 100
# 	Loss: 1.725137, Train accuracy: 0.435444, val accuracy: 0.410000
# Started epoch 95 / 100
# 	Loss: 1.687055, Train accuracy: 0.440333, val accuracy: 0.413000
# Started epoch 96 / 100
# 	Loss: 1.711790, Train accuracy: 0.445000, val accuracy: 0.415000
# Started epoch 97 / 100
# 	Loss: 1.660249, Train accuracy: 0.450000, val accuracy: 0.417000
# Started epoch 98 / 100
# 	Loss: 1.643165, Train accuracy: 0.453778, val accuracy: 0.422000
# Started epoch 99 / 100
# 	Loss: 1.627277, Train accuracy: 0.459111, val accuracy: 0.427000
#
# New best_val_accuracy: 0.427
# New params: {'learning_rate': 0.01, 'reg_strength': 0.001, 'learning_rate_decay': 0.999}
#
# Started learning with new params
#
# Started epoch 0 / 100
# 	Loss: 2.303142, Train accuracy: 0.168111, val accuracy: 0.164000
# Started epoch 1 / 100
# 	Loss: 2.303083, Train accuracy: 0.193111, val accuracy: 0.186000
# Started epoch 2 / 100
# 	Loss: 2.303030, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 3 / 100
# 	Loss: 2.303059, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 4 / 100
# 	Loss: 2.303007, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 5 / 100
# 	Loss: 2.303020, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 6 / 100
# 	Loss: 2.303045, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 7 / 100
# 	Loss: 2.303085, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 8 / 100
# 	Loss: 2.303049, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 9 / 100
# 	Loss: 2.303080, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 10 / 100
# 	Loss: 2.303030, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 11 / 100
# 	Loss: 2.303019, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 12 / 100
# 	Loss: 2.303050, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 13 / 100
# 	Loss: 2.303034, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 14 / 100
# 	Loss: 2.303031, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 15 / 100
# 	Loss: 2.303055, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 16 / 100
# 	Loss: 2.303054, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 17 / 100
# 	Loss: 2.303015, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 18 / 100
# 	Loss: 2.303010, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 19 / 100
# 	Loss: 2.303034, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 20 / 100
# 	Loss: 2.303021, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 21 / 100
# 	Loss: 2.303035, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 22 / 100
# 	Loss: 2.303051, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 23 / 100
# 	Loss: 2.302984, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 24 / 100
# 	Loss: 2.303004, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 25 / 100
# 	Loss: 2.303065, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 26 / 100
# 	Loss: 2.303010, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 27 / 100
# 	Loss: 2.303022, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 28 / 100
# 	Loss: 2.303052, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 29 / 100
# 	Loss: 2.303056, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 30 / 100
# 	Loss: 2.302987, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 31 / 100
# 	Loss: 2.303038, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 32 / 100
# 	Loss: 2.303004, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 33 / 100
# 	Loss: 2.303069, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 34 / 100
# 	Loss: 2.303049, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 35 / 100
# 	Loss: 2.303067, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 36 / 100
# 	Loss: 2.303052, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 37 / 100
# 	Loss: 2.303025, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 38 / 100
# 	Loss: 2.303022, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 39 / 100
# 	Loss: 2.303041, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 40 / 100
# 	Loss: 2.303052, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 41 / 100
# 	Loss: 2.303079, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 42 / 100
# 	Loss: 2.303017, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 43 / 100
# 	Loss: 2.303012, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 44 / 100
# 	Loss: 2.303071, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 45 / 100
# 	Loss: 2.302991, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 46 / 100
# 	Loss: 2.302993, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 47 / 100
# 	Loss: 2.303053, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 48 / 100
# 	Loss: 2.303011, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 49 / 100
# 	Loss: 2.303064, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 50 / 100
# 	Loss: 2.303050, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 51 / 100
# 	Loss: 2.303079, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 52 / 100
# 	Loss: 2.302999, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 53 / 100
# 	Loss: 2.303078, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 54 / 100
# 	Loss: 2.303041, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 55 / 100
# 	Loss: 2.303038, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 56 / 100
# 	Loss: 2.303065, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 57 / 100
# 	Loss: 2.303003, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 58 / 100
# 	Loss: 2.303039, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 59 / 100
# 	Loss: 2.303018, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 60 / 100
# 	Loss: 2.303013, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 61 / 100
# 	Loss: 2.303026, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 62 / 100
# 	Loss: 2.303043, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 63 / 100
# 	Loss: 2.303050, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 64 / 100
# 	Loss: 2.303033, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 65 / 100
# 	Loss: 2.303025, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 66 / 100
# 	Loss: 2.303036, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 67 / 100
# 	Loss: 2.303013, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 68 / 100
# 	Loss: 2.303000, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 69 / 100
# 	Loss: 2.303053, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 70 / 100
# 	Loss: 2.303033, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 71 / 100
# 	Loss: 2.303055, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 72 / 100
# 	Loss: 2.303059, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 73 / 100
# 	Loss: 2.303034, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 74 / 100
# 	Loss: 2.303002, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 75 / 100
# 	Loss: 2.303065, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 76 / 100
# 	Loss: 2.303058, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 77 / 100
# 	Loss: 2.303034, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 78 / 100
# 	Loss: 2.303070, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 79 / 100
# 	Loss: 2.303052, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 80 / 100
# 	Loss: 2.303018, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 81 / 100
# 	Loss: 2.303033, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 82 / 100
# 	Loss: 2.303024, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 83 / 100
# 	Loss: 2.303039, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 84 / 100
# 	Loss: 2.303010, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 85 / 100
# 	Loss: 2.303079, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 86 / 100
# 	Loss: 2.303026, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 87 / 100
# 	Loss: 2.303025, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 88 / 100
# 	Loss: 2.303036, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 89 / 100
# 	Loss: 2.302998, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 90 / 100
# 	Loss: 2.303060, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 91 / 100
# 	Loss: 2.303070, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 92 / 100
# 	Loss: 2.303068, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 93 / 100
# 	Loss: 2.303038, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 94 / 100
# 	Loss: 2.303056, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 95 / 100
# 	Loss: 2.303006, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 96 / 100
# 	Loss: 2.303050, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 97 / 100
# 	Loss: 2.303036, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 98 / 100
# 	Loss: 2.303025, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 99 / 100
# 	Loss: 2.303015, Train accuracy: 0.193222, val accuracy: 0.187000
#
# Started learning with new params
#
# Started epoch 0 / 100
# 	Loss: 2.308406, Train accuracy: 0.151222, val accuracy: 0.159000
# Started epoch 1 / 100
# 	Loss: 2.307402, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 2 / 100
# 	Loss: 2.306038, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 3 / 100
# 	Loss: 2.304912, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 4 / 100
# 	Loss: 2.303008, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 5 / 100
# 	Loss: 2.302176, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 6 / 100
# 	Loss: 2.300598, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 7 / 100
# 	Loss: 2.299259, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 8 / 100
# 	Loss: 2.299049, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 9 / 100
# 	Loss: 2.297775, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 10 / 100
# 	Loss: 2.296630, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 11 / 100
# 	Loss: 2.294714, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 12 / 100
# 	Loss: 2.294087, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 13 / 100
# 	Loss: 2.293780, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 14 / 100
# 	Loss: 2.295940, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 15 / 100
# 	Loss: 2.291274, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 16 / 100
# 	Loss: 2.287590, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 17 / 100
# 	Loss: 2.286916, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 18 / 100
# 	Loss: 2.285851, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 19 / 100
# 	Loss: 2.288666, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 20 / 100
# 	Loss: 2.286235, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 21 / 100
# 	Loss: 2.283041, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 22 / 100
# 	Loss: 2.285372, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 23 / 100
# 	Loss: 2.279200, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 24 / 100
# 	Loss: 2.286215, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 25 / 100
# 	Loss: 2.278953, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 26 / 100
# 	Loss: 2.284824, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 27 / 100
# 	Loss: 2.287087, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 28 / 100
# 	Loss: 2.278689, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 29 / 100
# 	Loss: 2.278006, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 30 / 100
# 	Loss: 2.272099, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 31 / 100
# 	Loss: 2.280277, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 32 / 100
# 	Loss: 2.273495, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 33 / 100
# 	Loss: 2.272161, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 34 / 100
# 	Loss: 2.277294, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 35 / 100
# 	Loss: 2.274439, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 36 / 100
# 	Loss: 2.276865, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 37 / 100
# 	Loss: 2.275926, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 38 / 100
# 	Loss: 2.270004, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 39 / 100
# 	Loss: 2.269491, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 40 / 100
# 	Loss: 2.275270, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 41 / 100
# 	Loss: 2.262049, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 42 / 100
# 	Loss: 2.274744, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 43 / 100
# 	Loss: 2.261780, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 44 / 100
# 	Loss: 2.269000, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 45 / 100
# 	Loss: 2.269771, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 46 / 100
# 	Loss: 2.269366, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 47 / 100
# 	Loss: 2.274689, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 48 / 100
# 	Loss: 2.264171, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 49 / 100
# 	Loss: 2.273451, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 50 / 100
# 	Loss: 2.269674, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 51 / 100
# 	Loss: 2.270633, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 52 / 100
# 	Loss: 2.264042, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 53 / 100
# 	Loss: 2.265350, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 54 / 100
# 	Loss: 2.267738, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 55 / 100
# 	Loss: 2.259151, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 56 / 100
# 	Loss: 2.264594, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 57 / 100
# 	Loss: 2.262295, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 58 / 100
# 	Loss: 2.269114, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 59 / 100
# 	Loss: 2.268662, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 60 / 100
# 	Loss: 2.264634, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 61 / 100
# 	Loss: 2.261447, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 62 / 100
# 	Loss: 2.268326, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 63 / 100
# 	Loss: 2.248907, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 64 / 100
# 	Loss: 2.251846, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 65 / 100
# 	Loss: 2.258312, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 66 / 100
# 	Loss: 2.254554, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 67 / 100
# 	Loss: 2.276302, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 68 / 100
# 	Loss: 2.252562, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 69 / 100
# 	Loss: 2.258955, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 70 / 100
# 	Loss: 2.255499, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 71 / 100
# 	Loss: 2.254719, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 72 / 100
# 	Loss: 2.256935, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 73 / 100
# 	Loss: 2.269060, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 74 / 100
# 	Loss: 2.252266, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 75 / 100
# 	Loss: 2.259723, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 76 / 100
# 	Loss: 2.257603, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 77 / 100
# 	Loss: 2.253194, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 78 / 100
# 	Loss: 2.257722, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 79 / 100
# 	Loss: 2.252160, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 80 / 100
# 	Loss: 2.251331, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 81 / 100
# 	Loss: 2.265664, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 82 / 100
# 	Loss: 2.273683, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 83 / 100
# 	Loss: 2.245670, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 84 / 100
# 	Loss: 2.250360, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 85 / 100
# 	Loss: 2.259994, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 86 / 100
# 	Loss: 2.256916, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 87 / 100
# 	Loss: 2.266468, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 88 / 100
# 	Loss: 2.245406, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 89 / 100
# 	Loss: 2.241263, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 90 / 100
# 	Loss: 2.258724, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 91 / 100
# 	Loss: 2.256641, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 92 / 100
# 	Loss: 2.259200, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 93 / 100
# 	Loss: 2.251065, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 94 / 100
# 	Loss: 2.257494, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 95 / 100
# 	Loss: 2.259146, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 96 / 100
# 	Loss: 2.257664, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 97 / 100
# 	Loss: 2.253949, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 98 / 100
# 	Loss: 2.259906, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 99 / 100
# 	Loss: 2.245033, Train accuracy: 0.193222, val accuracy: 0.187000
#
# Started learning with new params
#
# Started epoch 0 / 100
# 	Loss: 2.273696, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 1 / 100
# 	Loss: 2.242893, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 2 / 100
# 	Loss: 2.251447, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 3 / 100
# 	Loss: 2.243271, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 4 / 100
# 	Loss: 2.235046, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 5 / 100
# 	Loss: 2.243040, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 6 / 100
# 	Loss: 2.227655, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 7 / 100
# 	Loss: 2.239770, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 8 / 100
# 	Loss: 2.224015, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 9 / 100
# 	Loss: 2.222407, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 10 / 100
# 	Loss: 2.205845, Train accuracy: 0.193222, val accuracy: 0.187000
# Started epoch 11 / 100
# 	Loss: 2.159008, Train accuracy: 0.197778, val accuracy: 0.190000
# Started epoch 12 / 100
# 	Loss: 2.147551, Train accuracy: 0.209667, val accuracy: 0.207000
# Started epoch 13 / 100
# 	Loss: 2.157354, Train accuracy: 0.218778, val accuracy: 0.217000
# Started epoch 14 / 100
# 	Loss: 2.173714, Train accuracy: 0.229556, val accuracy: 0.223000
# Started epoch 15 / 100
# 	Loss: 2.158655, Train accuracy: 0.234222, val accuracy: 0.236000
# Started epoch 16 / 100
# 	Loss: 2.132865, Train accuracy: 0.238111, val accuracy: 0.234000
# Started epoch 17 / 100
# 	Loss: 2.109806, Train accuracy: 0.245556, val accuracy: 0.248000
# Started epoch 18 / 100
# 	Loss: 2.105762, Train accuracy: 0.247111, val accuracy: 0.248000
# Started epoch 19 / 100
# 	Loss: 2.133831, Train accuracy: 0.252444, val accuracy: 0.253000
# Started epoch 20 / 100
# 	Loss: 2.119168, Train accuracy: 0.254778, val accuracy: 0.253000
# Started epoch 21 / 100
# 	Loss: 2.108083, Train accuracy: 0.256444, val accuracy: 0.256000
# Started epoch 22 / 100
# 	Loss: 2.084939, Train accuracy: 0.258556, val accuracy: 0.261000
# Started epoch 23 / 100
# 	Loss: 2.099321, Train accuracy: 0.260889, val accuracy: 0.258000
# Started epoch 24 / 100
# 	Loss: 2.081797, Train accuracy: 0.263444, val accuracy: 0.262000
# Started epoch 25 / 100
# 	Loss: 2.095029, Train accuracy: 0.265889, val accuracy: 0.266000
# Started epoch 26 / 100
# 	Loss: 2.087455, Train accuracy: 0.268556, val accuracy: 0.265000
# Started epoch 27 / 100
# 	Loss: 2.072595, Train accuracy: 0.269333, val accuracy: 0.267000
# Started epoch 28 / 100
# 	Loss: 2.105679, Train accuracy: 0.271444, val accuracy: 0.270000
# Started epoch 29 / 100
# 	Loss: 2.141089, Train accuracy: 0.273333, val accuracy: 0.270000
# Started epoch 30 / 100
# 	Loss: 2.115664, Train accuracy: 0.274556, val accuracy: 0.271000
# Started epoch 31 / 100
# 	Loss: 2.097017, Train accuracy: 0.275667, val accuracy: 0.271000
# Started epoch 32 / 100
# 	Loss: 2.068166, Train accuracy: 0.277000, val accuracy: 0.273000
# Started epoch 33 / 100
# 	Loss: 2.085642, Train accuracy: 0.278556, val accuracy: 0.275000
# Started epoch 34 / 100
# 	Loss: 2.108295, Train accuracy: 0.279778, val accuracy: 0.275000
# Started epoch 35 / 100
# 	Loss: 2.105364, Train accuracy: 0.280667, val accuracy: 0.275000
# Started epoch 36 / 100
# 	Loss: 2.063056, Train accuracy: 0.281889, val accuracy: 0.278000
# Started epoch 37 / 100
# 	Loss: 2.088694, Train accuracy: 0.282556, val accuracy: 0.280000
# Started epoch 38 / 100
# 	Loss: 2.080761, Train accuracy: 0.283667, val accuracy: 0.284000
# Started epoch 39 / 100
# 	Loss: 2.101265, Train accuracy: 0.283889, val accuracy: 0.283000
# Started epoch 40 / 100
# 	Loss: 2.104829, Train accuracy: 0.285000, val accuracy: 0.285000
# Started epoch 41 / 100
# 	Loss: 2.093263, Train accuracy: 0.285333, val accuracy: 0.285000
# Started epoch 42 / 100
# 	Loss: 2.072473, Train accuracy: 0.286222, val accuracy: 0.285000
# Started epoch 43 / 100
# 	Loss: 2.074543, Train accuracy: 0.286556, val accuracy: 0.286000
# Started epoch 44 / 100
# 	Loss: 2.106066, Train accuracy: 0.287222, val accuracy: 0.287000
# Started epoch 45 / 100
# 	Loss: 2.051765, Train accuracy: 0.287889, val accuracy: 0.287000
# Started epoch 46 / 100
# 	Loss: 2.064005, Train accuracy: 0.288111, val accuracy: 0.287000
# Started epoch 47 / 100
# 	Loss: 2.050591, Train accuracy: 0.288444, val accuracy: 0.287000
# Started epoch 48 / 100
# 	Loss: 2.068775, Train accuracy: 0.288667, val accuracy: 0.287000
# Started epoch 49 / 100
# 	Loss: 2.056538, Train accuracy: 0.289111, val accuracy: 0.289000
# Started epoch 50 / 100
# 	Loss: 2.044657, Train accuracy: 0.289000, val accuracy: 0.289000
# Started epoch 51 / 100
# 	Loss: 2.067380, Train accuracy: 0.289333, val accuracy: 0.289000
# Started epoch 52 / 100
# 	Loss: 2.082629, Train accuracy: 0.289556, val accuracy: 0.289000
# Started epoch 53 / 100
# 	Loss: 2.058424, Train accuracy: 0.289778, val accuracy: 0.289000
# Started epoch 54 / 100
# 	Loss: 2.079574, Train accuracy: 0.289889, val accuracy: 0.289000
# Started epoch 55 / 100
# 	Loss: 2.053574, Train accuracy: 0.290000, val accuracy: 0.289000
# Started epoch 56 / 100
# 	Loss: 2.054530, Train accuracy: 0.290111, val accuracy: 0.289000
# Started epoch 57 / 100
# 	Loss: 2.061170, Train accuracy: 0.290000, val accuracy: 0.289000
# Started epoch 58 / 100
# 	Loss: 2.086412, Train accuracy: 0.290222, val accuracy: 0.289000
# Started epoch 59 / 100
# 	Loss: 2.071507, Train accuracy: 0.290333, val accuracy: 0.289000
# Started epoch 60 / 100
# 	Loss: 2.060844, Train accuracy: 0.291000, val accuracy: 0.289000
# Started epoch 61 / 100
# 	Loss: 2.063440, Train accuracy: 0.291000, val accuracy: 0.289000
# Started epoch 62 / 100
# 	Loss: 2.069703, Train accuracy: 0.291111, val accuracy: 0.289000
# Started epoch 63 / 100
# 	Loss: 2.055896, Train accuracy: 0.291111, val accuracy: 0.289000
# Started epoch 64 / 100
# 	Loss: 2.074381, Train accuracy: 0.291111, val accuracy: 0.289000
# Started epoch 65 / 100
# 	Loss: 2.080433, Train accuracy: 0.291111, val accuracy: 0.289000
# Started epoch 66 / 100
# 	Loss: 2.074549, Train accuracy: 0.291111, val accuracy: 0.289000
# Started epoch 67 / 100
# 	Loss: 2.062744, Train accuracy: 0.291111, val accuracy: 0.289000
# Started epoch 68 / 100
# 	Loss: 2.084659, Train accuracy: 0.291111, val accuracy: 0.290000
# Started epoch 69 / 100
# 	Loss: 2.078577, Train accuracy: 0.291111, val accuracy: 0.290000
# Started epoch 70 / 100
# 	Loss: 2.093705, Train accuracy: 0.291111, val accuracy: 0.290000
# Started epoch 71 / 100
# 	Loss: 2.058882, Train accuracy: 0.291333, val accuracy: 0.290000
# Started epoch 72 / 100
# 	Loss: 2.055886, Train accuracy: 0.291333, val accuracy: 0.290000
# Started epoch 73 / 100
# 	Loss: 2.047269, Train accuracy: 0.291556, val accuracy: 0.290000
# Started epoch 74 / 100
# 	Loss: 2.073792, Train accuracy: 0.291556, val accuracy: 0.290000
# Started epoch 75 / 100
# 	Loss: 2.084326, Train accuracy: 0.291556, val accuracy: 0.290000
# Started epoch 76 / 100
# 	Loss: 2.060657, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 77 / 100
# 	Loss: 2.084239, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 78 / 100
# 	Loss: 2.067033, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 79 / 100
# 	Loss: 2.056197, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 80 / 100
# 	Loss: 2.064608, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 81 / 100
# 	Loss: 2.069629, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 82 / 100
# 	Loss: 2.111946, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 83 / 100
# 	Loss: 2.084349, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 84 / 100
# 	Loss: 2.090547, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 85 / 100
# 	Loss: 2.099942, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 86 / 100
# 	Loss: 2.106365, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 87 / 100
# 	Loss: 2.086725, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 88 / 100
# 	Loss: 2.065601, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 89 / 100
# 	Loss: 2.109023, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 90 / 100
# 	Loss: 2.110902, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 91 / 100
# 	Loss: 2.061941, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 92 / 100
# 	Loss: 2.088290, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 93 / 100
# 	Loss: 2.070600, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 94 / 100
# 	Loss: 2.072293, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 95 / 100
# 	Loss: 2.079742, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 96 / 100
# 	Loss: 2.065682, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 97 / 100
# 	Loss: 2.080880, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 98 / 100
# 	Loss: 2.072284, Train accuracy: 0.291667, val accuracy: 0.290000
# Started epoch 99 / 100
# 	Loss: 2.087471, Train accuracy: 0.291667, val accuracy: 0.290000
#
# Continue training best model with params: {'learning_rate': 0.01, 'reg_strength': 0.001, 'learning_rate_decay': 0.999}
#
# Started epoch 0 / 100
# 	Loss: 1.631677, Train accuracy: 0.461556, val accuracy: 0.427000
# Started epoch 1 / 100
# 	Loss: 1.644952, Train accuracy: 0.465556, val accuracy: 0.435000
# Started epoch 2 / 100
# 	Loss: 1.621378, Train accuracy: 0.471778, val accuracy: 0.434000
# Started epoch 3 / 100
# 	Loss: 1.653096, Train accuracy: 0.472889, val accuracy: 0.440000
# Started epoch 4 / 100
# 	Loss: 1.574090, Train accuracy: 0.478556, val accuracy: 0.444000
# Started epoch 5 / 100
# 	Loss: 1.591599, Train accuracy: 0.481444, val accuracy: 0.447000
# Started epoch 6 / 100
# 	Loss: 1.635979, Train accuracy: 0.486778, val accuracy: 0.450000
# Started epoch 7 / 100
# 	Loss: 1.575080, Train accuracy: 0.488667, val accuracy: 0.451000
# Started epoch 8 / 100
# 	Loss: 1.591979, Train accuracy: 0.494444, val accuracy: 0.457000
# Started epoch 9 / 100
# 	Loss: 1.514277, Train accuracy: 0.498111, val accuracy: 0.462000
# Started epoch 10 / 100
# 	Loss: 1.523782, Train accuracy: 0.504222, val accuracy: 0.464000
# Started epoch 11 / 100
# 	Loss: 1.552387, Train accuracy: 0.507333, val accuracy: 0.466000
# Started epoch 12 / 100
# 	Loss: 1.518778, Train accuracy: 0.512333, val accuracy: 0.467000
# Started epoch 13 / 100
# 	Loss: 1.515695, Train accuracy: 0.514333, val accuracy: 0.472000
# Started epoch 14 / 100
# 	Loss: 1.565959, Train accuracy: 0.518444, val accuracy: 0.474000
# Started epoch 15 / 100
# 	Loss: 1.504301, Train accuracy: 0.521444, val accuracy: 0.483000
# Started epoch 16 / 100
# 	Loss: 1.469442, Train accuracy: 0.525333, val accuracy: 0.491000
# Started epoch 17 / 100
# 	Loss: 1.436377, Train accuracy: 0.530111, val accuracy: 0.495000
# Started epoch 18 / 100
# 	Loss: 1.527183, Train accuracy: 0.535333, val accuracy: 0.502000
# Started epoch 19 / 100
# 	Loss: 1.501368, Train accuracy: 0.535889, val accuracy: 0.502000
# Started epoch 20 / 100
# 	Loss: 1.486730, Train accuracy: 0.540778, val accuracy: 0.509000
# Started epoch 21 / 100
# 	Loss: 1.516868, Train accuracy: 0.543333, val accuracy: 0.511000
# Started epoch 22 / 100
# 	Loss: 1.429339, Train accuracy: 0.547778, val accuracy: 0.519000
# Started epoch 23 / 100
# 	Loss: 1.459456, Train accuracy: 0.550222, val accuracy: 0.517000
# Started epoch 24 / 100
# 	Loss: 1.478810, Train accuracy: 0.553444, val accuracy: 0.522000
# Started epoch 25 / 100
# 	Loss: 1.487479, Train accuracy: 0.557222, val accuracy: 0.524000
# Started epoch 26 / 100
# 	Loss: 1.420856, Train accuracy: 0.560222, val accuracy: 0.532000
# Started epoch 27 / 100
# 	Loss: 1.440209, Train accuracy: 0.563778, val accuracy: 0.537000
# Started epoch 28 / 100
# 	Loss: 1.405321, Train accuracy: 0.566667, val accuracy: 0.538000
# Started epoch 29 / 100
# 	Loss: 1.455510, Train accuracy: 0.569778, val accuracy: 0.544000
# Started epoch 30 / 100
# 	Loss: 1.391330, Train accuracy: 0.571556, val accuracy: 0.550000
# Started epoch 31 / 100
# 	Loss: 1.402921, Train accuracy: 0.574111, val accuracy: 0.551000
# Started epoch 32 / 100
# 	Loss: 1.394794, Train accuracy: 0.578444, val accuracy: 0.551000
# Started epoch 33 / 100
# 	Loss: 1.420636, Train accuracy: 0.578667, val accuracy: 0.559000
# Started epoch 34 / 100
# 	Loss: 1.342497, Train accuracy: 0.580556, val accuracy: 0.559000
# Started epoch 35 / 100
# 	Loss: 1.398125, Train accuracy: 0.584111, val accuracy: 0.564000
# Started epoch 36 / 100
# 	Loss: 1.404042, Train accuracy: 0.586000, val accuracy: 0.562000
# Started epoch 37 / 100
# 	Loss: 1.358349, Train accuracy: 0.589889, val accuracy: 0.566000
# Started epoch 38 / 100
# 	Loss: 1.355855, Train accuracy: 0.591000, val accuracy: 0.566000
# Started epoch 39 / 100
# 	Loss: 1.357565, Train accuracy: 0.593778, val accuracy: 0.568000
# Started epoch 40 / 100
# 	Loss: 1.315299, Train accuracy: 0.595667, val accuracy: 0.572000
# Started epoch 41 / 100
# 	Loss: 1.381383, Train accuracy: 0.598000, val accuracy: 0.570000
# Started epoch 42 / 100
# 	Loss: 1.329788, Train accuracy: 0.600222, val accuracy: 0.575000
# Started epoch 43 / 100
# 	Loss: 1.342799, Train accuracy: 0.602333, val accuracy: 0.579000
# Started epoch 44 / 100
# 	Loss: 1.283435, Train accuracy: 0.605111, val accuracy: 0.584000
# Started epoch 45 / 100
# 	Loss: 1.334818, Train accuracy: 0.607333, val accuracy: 0.585000
# Started epoch 46 / 100
# 	Loss: 1.324509, Train accuracy: 0.610444, val accuracy: 0.580000
# Started epoch 47 / 100
# 	Loss: 1.318257, Train accuracy: 0.612778, val accuracy: 0.586000
# Started epoch 48 / 100
# 	Loss: 1.337997, Train accuracy: 0.615778, val accuracy: 0.594000
# Started epoch 49 / 100
# 	Loss: 1.367723, Train accuracy: 0.616556, val accuracy: 0.592000
# Started epoch 50 / 100
# 	Loss: 1.321712, Train accuracy: 0.620222, val accuracy: 0.599000
# Started epoch 51 / 100
# 	Loss: 1.273583, Train accuracy: 0.622667, val accuracy: 0.598000
# Started epoch 52 / 100
# 	Loss: 1.246055, Train accuracy: 0.625222, val accuracy: 0.596000
# Started epoch 53 / 100
# 	Loss: 1.290349, Train accuracy: 0.628111, val accuracy: 0.598000
# Started epoch 54 / 100
# 	Loss: 1.296399, Train accuracy: 0.627889, val accuracy: 0.601000
# Started epoch 55 / 100
# 	Loss: 1.336704, Train accuracy: 0.630667, val accuracy: 0.599000
# Started epoch 56 / 100
# 	Loss: 1.295949, Train accuracy: 0.632889, val accuracy: 0.602000
# Started epoch 57 / 100
# 	Loss: 1.287071, Train accuracy: 0.634333, val accuracy: 0.602000
# Started epoch 58 / 100
# 	Loss: 1.298314, Train accuracy: 0.635889, val accuracy: 0.601000
# Started epoch 59 / 100
# 	Loss: 1.236737, Train accuracy: 0.638889, val accuracy: 0.606000
# Started epoch 60 / 100
# 	Loss: 1.302968, Train accuracy: 0.639889, val accuracy: 0.604000
# Started epoch 61 / 100
# 	Loss: 1.234057, Train accuracy: 0.641889, val accuracy: 0.605000
# Started epoch 62 / 100
# 	Loss: 1.193312, Train accuracy: 0.644667, val accuracy: 0.612000
# Started epoch 63 / 100
# 	Loss: 1.258565, Train accuracy: 0.646333, val accuracy: 0.609000
# Started epoch 64 / 100
# 	Loss: 1.242646, Train accuracy: 0.647556, val accuracy: 0.617000
# Started epoch 65 / 100
# 	Loss: 1.249260, Train accuracy: 0.649889, val accuracy: 0.608000
# Started epoch 66 / 100
# 	Loss: 1.186311, Train accuracy: 0.650333, val accuracy: 0.618000
# Started epoch 67 / 100
# 	Loss: 1.219864, Train accuracy: 0.653333, val accuracy: 0.610000
# Started epoch 68 / 100
# 	Loss: 1.204775, Train accuracy: 0.655667, val accuracy: 0.617000
# Started epoch 69 / 100
# 	Loss: 1.222050, Train accuracy: 0.657667, val accuracy: 0.620000
# Started epoch 70 / 100
# 	Loss: 1.227853, Train accuracy: 0.659333, val accuracy: 0.621000
# Started epoch 71 / 100
# 	Loss: 1.204124, Train accuracy: 0.662333, val accuracy: 0.622000
# Started epoch 72 / 100
# 	Loss: 1.278589, Train accuracy: 0.662667, val accuracy: 0.624000
# Started epoch 73 / 100
# 	Loss: 1.206041, Train accuracy: 0.663444, val accuracy: 0.628000
# Started epoch 74 / 100
# 	Loss: 1.245476, Train accuracy: 0.666444, val accuracy: 0.629000
# Started epoch 75 / 100
# 	Loss: 1.179246, Train accuracy: 0.666556, val accuracy: 0.626000
# Started epoch 76 / 100
# 	Loss: 1.186325, Train accuracy: 0.669111, val accuracy: 0.630000
# Started epoch 77 / 100
# 	Loss: 1.201131, Train accuracy: 0.670778, val accuracy: 0.627000
# Started epoch 78 / 100
# 	Loss: 1.209564, Train accuracy: 0.671111, val accuracy: 0.629000
# Started epoch 79 / 100
# 	Loss: 1.169136, Train accuracy: 0.672778, val accuracy: 0.633000
# Started epoch 80 / 100
# 	Loss: 1.179791, Train accuracy: 0.675222, val accuracy: 0.630000
# Started epoch 81 / 100
# 	Loss: 1.207482, Train accuracy: 0.678111, val accuracy: 0.628000
# Started epoch 82 / 100
# 	Loss: 1.148205, Train accuracy: 0.677111, val accuracy: 0.635000
# Started epoch 83 / 100
# 	Loss: 1.180466, Train accuracy: 0.680333, val accuracy: 0.633000
# Started epoch 84 / 100
# 	Loss: 1.205982, Train accuracy: 0.680889, val accuracy: 0.635000
# Started epoch 85 / 100
# 	Loss: 1.178416, Train accuracy: 0.683000, val accuracy: 0.640000
# Started epoch 86 / 100
# 	Loss: 1.111270, Train accuracy: 0.684556, val accuracy: 0.637000
# Started epoch 87 / 100
# 	Loss: 1.154671, Train accuracy: 0.684667, val accuracy: 0.640000
# Started epoch 88 / 100
# 	Loss: 1.145387, Train accuracy: 0.687222, val accuracy: 0.637000
# Started epoch 89 / 100
# 	Loss: 1.122809, Train accuracy: 0.688222, val accuracy: 0.641000
# Started epoch 90 / 100
# 	Loss: 1.122801, Train accuracy: 0.690111, val accuracy: 0.645000
# Started epoch 91 / 100
# 	Loss: 1.138513, Train accuracy: 0.690889, val accuracy: 0.643000
# Started epoch 92 / 100
# 	Loss: 1.117861, Train accuracy: 0.691111, val accuracy: 0.647000
# Started epoch 93 / 100
# 	Loss: 1.172710, Train accuracy: 0.693556, val accuracy: 0.646000
# Started epoch 94 / 100
# 	Loss: 1.112970, Train accuracy: 0.695111, val accuracy: 0.652000
# Started epoch 95 / 100
# 	Loss: 1.132539, Train accuracy: 0.694556, val accuracy: 0.648000
# Started epoch 96 / 100
# 	Loss: 1.150796, Train accuracy: 0.697222, val accuracy: 0.648000
# Started epoch 97 / 100
# 	Loss: 1.143825, Train accuracy: 0.699000, val accuracy: 0.653000
# Started epoch 98 / 100
# 	Loss: 1.104801, Train accuracy: 0.700000, val accuracy: 0.649000
# Started epoch 99 / 100
# 	Loss: 1.120649, Train accuracy: 0.700889, val accuracy: 0.655000
#
# best validation accuracy achieved: 0.655000

# %%
# Continue training best model with params: {'learning_rate': 0.01, 'reg_strength': 0.001, 'learning_rate_decay': 0.999}
plt.figure(figsize=(15, 7))
plt.subplot(211)
plt.title("Loss")
plt.plot(best_classifier_history[0])
plt.subplot(212)
plt.title("Train/validation accuracy")
plt.plot(best_classifier_history[1])
plt.plot(best_classifier_history[2])

# %% [markdown]
# # Как обычно, посмотрим, как наша лучшая модель работает на тестовых данных

# %%
test_pred = best_classifier.predict(test_X)
test_accuracy = multiclass_accuracy(test_pred, test_y)
print('Neural net test set accuracy: %f' % (test_accuracy, ))
# Out:
# Neural net test set accuracy: 0.677000
